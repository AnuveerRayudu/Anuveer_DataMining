# %%
import pandas as pd
import itertools
import time

# Load transactions from a CSV file, processing the items column into a list of sets
def load_transactions(file_path):
    df = pd.read_csv(file_path, usecols=[1], skiprows=1, names=['items'])
    return [set(item.split(", ")) for item in df['items']]

# Function to calculate support of an itemset within the transactions
def calculate_support(itemset, transactions):
    return sum(1 for transaction in transactions if itemset.issubset(transaction))

# Generate frequent itemsets based on minimum support
def find_frequent_itemsets(transactions, min_support, max_length=3):
    items_pool = {item for transaction in transactions for item in transaction}
    frequent_itemsets = []
    
    for size in range(1, max_length + 1):
        for combination in itertools.combinations(items_pool, size):
            support_count = calculate_support(set(combination), transactions)
            if support_count >= min_support:
                frequent_itemsets.append((set(combination), support_count))
    
    return frequent_itemsets

# Generate association rules based on frequent itemsets
def generate_rules(frequent_itemsets, transactions, min_confidence):
    rules = []
    
    for itemset, support_count in frequent_itemsets:
        for subset_size in range(1, len(itemset)):
            for subset in itertools.combinations(itemset, subset_size):
                subset = set(subset)
                remainder = itemset - subset
                if remainder:
                    subset_support = calculate_support(subset, transactions)
                    confidence = support_count / subset_support if subset_support > 0 else 0
                    if confidence >= min_confidence:
                        rules.append((subset, remainder, confidence))
    
    return rules

# Main function to process a CSV file, find itemsets, and generate rules
def process_transactions(file_path, min_support, min_confidence):
    transactions = load_transactions(file_path)
    min_support_count = int(min_support * len(transactions))  # Convert to absolute support count
    frequent_itemsets = find_frequent_itemsets(transactions, min_support_count)
    association_rules = generate_rules(frequent_itemsets, transactions, min_confidence)
    
    return frequent_itemsets, association_rules

# Start execution timer
start_time = time.time()

# Provided datasets
datasets = {
    'Target': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\target_data_new.csv',
    'Costco': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\costco_data_new.csv',
    '7-Eleven': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\seven_eleven_data.csv',
    'ShopRite': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\shoprite_data.csv',
    'K-Mart': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\kmart_data.csv'
}

# Minimum support and confidence
min_support = 0.05
min_confidence = 0.3

# Analyze each dataset
for store, file_path in datasets.items():
    itemsets, rules = process_transactions(file_path, min_support, min_confidence)
    print(f"Results for {store}:")
    print("Frequent Itemsets:", itemsets)
    print("Association Rules:", rules)
    print("\n")

# Total execution time
print(f"Total Execution Time: {time.time() - start_time:.2f} seconds")
# Out:
# Results for Target:
# Frequent Itemsets: [({'Toys'}, 278), ({'Gardening Supplies'}, 287), ({'Clothes'}, 287), ({'Bedding'}, 291), ({'Furniture'}, 329), ({'Beauty Products'}, 292), ({'Stationery'}, 320), ({'Groceries'}, 286), ({'Electronics'}, 309), ({'Cleaning Supplies'}, 295), ({'Toys', 'Gardening Supplies'}, 71), ({'Toys', 'Clothes'}, 77), ({'Toys', 'Bedding'}, 73), ({'Furniture', 'Toys'}, 82), ({'Beauty Products', 'Toys'}, 77), ({'Stationery', 'Toys'}, 87), ({'Groceries', 'Toys'}, 82), ({'Toys', 'Electronics'}, 91), ({'Toys', 'Cleaning Supplies'}, 74), ({'Clothes', 'Gardening Supplies'}, 89), ({'Gardening Supplies', 'Bedding'}, 85), ({'Furniture', 'Gardening Supplies'}, 97), ({'Beauty Products', 'Gardening Supplies'}, 82), ({'Stationery', 'Gardening Supplies'}, 95), ({'Groceries', 'Gardening Supplies'}, 83), ({'Electronics', 'Gardening Supplies'}, 87), ({'Gardening Supplies', 'Cleaning Supplies'}, 89), ({'Clothes', 'Bedding'}, 80), ({'Furniture', 'Clothes'}, 89), ({'Beauty Products', 'Clothes'}, 77), ({'Stationery', 'Clothes'}, 93), ({'Groceries', 'Clothes'}, 73), ({'Clothes', 'Electronics'}, 81), ({'Clothes', 'Cleaning Supplies'}, 87), ({'Furniture', 'Bedding'}, 90), ({'Beauty Products', 'Bedding'}, 89), ({'Stationery', 'Bedding'}, 97), ({'Groceries', 'Bedding'}, 83), ({'Electronics', 'Bedding'}, 92), ({'Cleaning Supplies', 'Bedding'}, 81), ({'Furniture', 'Beauty Products'}, 94), ({'Stationery', 'Furniture'}, 101), ({'Furniture', 'Groceries'}, 100), ({'Furniture', 'Electronics'}, 98), ({'Furniture', 'Cleaning Supplies'}, 101), ({'Stationery', 'Beauty Products'}, 97), ({'Groceries', 'Beauty Products'}, 79), ({'Beauty Products', 'Electronics'}, 92), ({'Beauty Products', 'Cleaning Supplies'}, 83), ({'Stationery', 'Groceries'}, 87), ({'Stationery', 'Electronics'}, 99), ({'Stationery', 'Cleaning Supplies'}, 97), ({'Groceries', 'Electronics'}, 97), ({'Groceries', 'Cleaning Supplies'}, 91), ({'Electronics', 'Cleaning Supplies'}, 97)]
# Association Rules: [({'Toys'}, {'Stationery'}, 0.3129496402877698), ({'Toys'}, {'Electronics'}, 0.3273381294964029), ({'Clothes'}, {'Gardening Supplies'}, 0.31010452961672474), ({'Gardening Supplies'}, {'Clothes'}, 0.31010452961672474), ({'Gardening Supplies'}, {'Furniture'}, 0.33797909407665505), ({'Gardening Supplies'}, {'Stationery'}, 0.3310104529616725), ({'Gardening Supplies'}, {'Electronics'}, 0.30313588850174217), ({'Gardening Supplies'}, {'Cleaning Supplies'}, 0.31010452961672474), ({'Cleaning Supplies'}, {'Gardening Supplies'}, 0.3016949152542373), ({'Clothes'}, {'Furniture'}, 0.31010452961672474), ({'Clothes'}, {'Stationery'}, 0.3240418118466899), ({'Clothes'}, {'Cleaning Supplies'}, 0.30313588850174217), ({'Bedding'}, {'Furniture'}, 0.30927835051546393), ({'Beauty Products'}, {'Bedding'}, 0.3047945205479452), ({'Bedding'}, {'Beauty Products'}, 0.30584192439862545), ({'Stationery'}, {'Bedding'}, 0.303125), ({'Bedding'}, {'Stationery'}, 0.3333333333333333), ({'Bedding'}, {'Electronics'}, 0.3161512027491409), ({'Beauty Products'}, {'Furniture'}, 0.3219178082191781), ({'Stationery'}, {'Furniture'}, 0.315625), ({'Furniture'}, {'Stationery'}, 0.3069908814589666), ({'Furniture'}, {'Groceries'}, 0.303951367781155), ({'Groceries'}, {'Furniture'}, 0.34965034965034963), ({'Electronics'}, {'Furniture'}, 0.31715210355987056), ({'Furniture'}, {'Cleaning Supplies'}, 0.3069908814589666), ({'Cleaning Supplies'}, {'Furniture'}, 0.3423728813559322), ({'Stationery'}, {'Beauty Products'}, 0.303125), ({'Beauty Products'}, {'Stationery'}, 0.3321917808219178), ({'Beauty Products'}, {'Electronics'}, 0.3150684931506849), ({'Groceries'}, {'Stationery'}, 0.3041958041958042), ({'Stationery'}, {'Electronics'}, 0.309375), ({'Electronics'}, {'Stationery'}, 0.32038834951456313), ({'Stationery'}, {'Cleaning Supplies'}, 0.303125), ({'Cleaning Supplies'}, {'Stationery'}, 0.3288135593220339), ({'Groceries'}, {'Electronics'}, 0.33916083916083917), ({'Electronics'}, {'Groceries'}, 0.313915857605178), ({'Groceries'}, {'Cleaning Supplies'}, 0.3181818181818182), ({'Cleaning Supplies'}, {'Groceries'}, 0.30847457627118646), ({'Electronics'}, {'Cleaning Supplies'}, 0.313915857605178), ({'Cleaning Supplies'}, {'Electronics'}, 0.3288135593220339)]
#
#
# Results for Costco:
# Frequent Itemsets: [({'Optical Items'}, 513), ({'Packaged Foods'}, 285), ({'Bakery Items'}, 321), ({'Tires'}, 329), ({'Bulk Fruits'}, 307), ({'Garden Supplies'}, 300), ({'Jewelry'}, 301), ({'Canned Foods'}, 277), ({'Cleaning Supplies'}, 295), ({'Packaged Foods', 'Optical Items'}, 143), ({'Bakery Items', 'Optical Items'}, 163), ({'Tires', 'Optical Items'}, 172), ({'Bulk Fruits', 'Optical Items'}, 167), ({'Optical Items', 'Garden Supplies'}, 152), ({'Optical Items', 'Jewelry'}, 157), ({'Canned Foods', 'Optical Items'}, 153), ({'Optical Items', 'Cleaning Supplies'}, 158), ({'Packaged Foods', 'Bakery Items'}, 87), ({'Packaged Foods', 'Tires'}, 95), ({'Packaged Foods', 'Bulk Fruits'}, 74), ({'Packaged Foods', 'Garden Supplies'}, 82), ({'Packaged Foods', 'Jewelry'}, 87), ({'Packaged Foods', 'Canned Foods'}, 77), ({'Packaged Foods', 'Cleaning Supplies'}, 83), ({'Bakery Items', 'Tires'}, 102), ({'Bakery Items', 'Bulk Fruits'}, 91), ({'Bakery Items', 'Garden Supplies'}, 97), ({'Bakery Items', 'Jewelry'}, 96), ({'Bakery Items', 'Canned Foods'}, 93), ({'Bakery Items', 'Cleaning Supplies'}, 100), ({'Bulk Fruits', 'Tires'}, 91), ({'Tires', 'Garden Supplies'}, 106), ({'Tires', 'Jewelry'}, 101), ({'Canned Foods', 'Tires'}, 82), ({'Tires', 'Cleaning Supplies'}, 93), ({'Bulk Fruits', 'Garden Supplies'}, 87), ({'Bulk Fruits', 'Jewelry'}, 93), ({'Canned Foods', 'Bulk Fruits'}, 80), ({'Bulk Fruits', 'Cleaning Supplies'}, 105), ({'Garden Supplies', 'Jewelry'}, 100), ({'Canned Foods', 'Garden Supplies'}, 84), ({'Garden Supplies', 'Cleaning Supplies'}, 79), ({'Canned Foods', 'Jewelry'}, 68), ({'Cleaning Supplies', 'Jewelry'}, 92), ({'Canned Foods', 'Cleaning Supplies'}, 77), ({'Bakery Items', 'Tires', 'Optical Items'}, 52), ({'Bulk Fruits', 'Bakery Items', 'Optical Items'}, 53), ({'Bakery Items', 'Optical Items', 'Cleaning Supplies'}, 56), ({'Tires', 'Optical Items', 'Garden Supplies'}, 56), ({'Tires', 'Optical Items', 'Jewelry'}, 56), ({'Bulk Fruits', 'Optical Items', 'Jewelry'}, 52), ({'Bulk Fruits', 'Optical Items', 'Cleaning Supplies'}, 55), ({'Optical Items', 'Garden Supplies', 'Jewelry'}, 52)]
# Association Rules: [({'Packaged Foods'}, {'Optical Items'}, 0.5017543859649123), ({'Bakery Items'}, {'Optical Items'}, 0.5077881619937694), ({'Optical Items'}, {'Bakery Items'}, 0.31773879142300193), ({'Tires'}, {'Optical Items'}, 0.5227963525835866), ({'Optical Items'}, {'Tires'}, 0.33528265107212474), ({'Bulk Fruits'}, {'Optical Items'}, 0.5439739413680782), ({'Optical Items'}, {'Bulk Fruits'}, 0.3255360623781676), ({'Garden Supplies'}, {'Optical Items'}, 0.5066666666666667), ({'Optical Items'}, {'Jewelry'}, 0.3060428849902534), ({'Jewelry'}, {'Optical Items'}, 0.521594684385382), ({'Canned Foods'}, {'Optical Items'}, 0.5523465703971119), ({'Optical Items'}, {'Cleaning Supplies'}, 0.3079922027290448), ({'Cleaning Supplies'}, {'Optical Items'}, 0.535593220338983), ({'Packaged Foods'}, {'Bakery Items'}, 0.30526315789473685), ({'Packaged Foods'}, {'Tires'}, 0.3333333333333333), ({'Packaged Foods'}, {'Jewelry'}, 0.30526315789473685), ({'Bakery Items'}, {'Tires'}, 0.3177570093457944), ({'Tires'}, {'Bakery Items'}, 0.3100303951367781), ({'Bakery Items'}, {'Garden Supplies'}, 0.30218068535825543), ({'Garden Supplies'}, {'Bakery Items'}, 0.3233333333333333), ({'Jewelry'}, {'Bakery Items'}, 0.31893687707641194), ({'Canned Foods'}, {'Bakery Items'}, 0.33574007220216606), ({'Bakery Items'}, {'Cleaning Supplies'}, 0.3115264797507788), ({'Cleaning Supplies'}, {'Bakery Items'}, 0.3389830508474576), ({'Tires'}, {'Garden Supplies'}, 0.3221884498480243), ({'Garden Supplies'}, {'Tires'}, 0.35333333333333333), ({'Tires'}, {'Jewelry'}, 0.3069908814589666), ({'Jewelry'}, {'Tires'}, 0.33554817275747506), ({'Cleaning Supplies'}, {'Tires'}, 0.3152542372881356), ({'Bulk Fruits'}, {'Jewelry'}, 0.30293159609120524), ({'Jewelry'}, {'Bulk Fruits'}, 0.3089700996677741), ({'Bulk Fruits'}, {'Cleaning Supplies'}, 0.34201954397394135), ({'Cleaning Supplies'}, {'Bulk Fruits'}, 0.3559322033898305), ({'Garden Supplies'}, {'Jewelry'}, 0.3333333333333333), ({'Jewelry'}, {'Garden Supplies'}, 0.33222591362126247), ({'Canned Foods'}, {'Garden Supplies'}, 0.30324909747292417), ({'Cleaning Supplies'}, {'Jewelry'}, 0.31186440677966104), ({'Jewelry'}, {'Cleaning Supplies'}, 0.30564784053156147), ({'Bakery Items', 'Tires'}, {'Optical Items'}, 0.5098039215686274), ({'Bakery Items', 'Optical Items'}, {'Tires'}, 0.31901840490797545), ({'Optical Items', 'Tires'}, {'Bakery Items'}, 0.3023255813953488), ({'Bakery Items', 'Bulk Fruits'}, {'Optical Items'}, 0.5824175824175825), ({'Optical Items', 'Bulk Fruits'}, {'Bakery Items'}, 0.31736526946107785), ({'Bakery Items', 'Optical Items'}, {'Bulk Fruits'}, 0.32515337423312884), ({'Bakery Items', 'Optical Items'}, {'Cleaning Supplies'}, 0.34355828220858897), ({'Bakery Items', 'Cleaning Supplies'}, {'Optical Items'}, 0.56), ({'Optical Items', 'Cleaning Supplies'}, {'Bakery Items'}, 0.35443037974683544), ({'Optical Items', 'Tires'}, {'Garden Supplies'}, 0.32558139534883723), ({'Tires', 'Garden Supplies'}, {'Optical Items'}, 0.5283018867924528), ({'Optical Items', 'Garden Supplies'}, {'Tires'}, 0.3684210526315789), ({'Optical Items', 'Tires'}, {'Jewelry'}, 0.32558139534883723), ({'Tires', 'Jewelry'}, {'Optical Items'}, 0.5544554455445545), ({'Optical Items', 'Jewelry'}, {'Tires'}, 0.35668789808917195), ({'Optical Items', 'Bulk Fruits'}, {'Jewelry'}, 0.31137724550898205), ({'Bulk Fruits', 'Jewelry'}, {'Optical Items'}, 0.5591397849462365), ({'Optical Items', 'Jewelry'}, {'Bulk Fruits'}, 0.33121019108280253), ({'Optical Items', 'Bulk Fruits'}, {'Cleaning Supplies'}, 0.32934131736526945), ({'Bulk Fruits', 'Cleaning Supplies'}, {'Optical Items'}, 0.5238095238095238), ({'Optical Items', 'Cleaning Supplies'}, {'Bulk Fruits'}, 0.34810126582278483), ({'Optical Items', 'Garden Supplies'}, {'Jewelry'}, 0.34210526315789475), ({'Optical Items', 'Jewelry'}, {'Garden Supplies'}, 0.33121019108280253), ({'Garden Supplies', 'Jewelry'}, {'Optical Items'}, 0.52)]
#
#
# Results for 7-Eleven:
# Frequent Itemsets: [({'Energy Drinks'}, 284), ({'Snacks'}, 271), ({'Soft Drinks'}, 274), ({'Gum'}, 303), ({'Toiletries'}, 280), ({'Batteries'}, 297), ({'Candy'}, 321), ({'Magazine'}, 318), ({'Cigarettes'}, 286), ({'Milk'}, 314), ({'Energy Drinks', 'Snacks'}, 75), ({'Energy Drinks', 'Soft Drinks'}, 72), ({'Energy Drinks', 'Gum'}, 99), ({'Energy Drinks', 'Toiletries'}, 86), ({'Energy Drinks', 'Batteries'}, 64), ({'Energy Drinks', 'Candy'}, 89), ({'Magazine', 'Energy Drinks'}, 77), ({'Energy Drinks', 'Cigarettes'}, 95), ({'Energy Drinks', 'Milk'}, 82), ({'Snacks', 'Soft Drinks'}, 78), ({'Gum', 'Snacks'}, 82), ({'Toiletries', 'Snacks'}, 68), ({'Batteries', 'Snacks'}, 70), ({'Candy', 'Snacks'}, 84), ({'Magazine', 'Snacks'}, 75), ({'Cigarettes', 'Snacks'}, 71), ({'Milk', 'Snacks'}, 81), ({'Gum', 'Soft Drinks'}, 77), ({'Toiletries', 'Soft Drinks'}, 70), ({'Batteries', 'Soft Drinks'}, 76), ({'Candy', 'Soft Drinks'}, 90), ({'Magazine', 'Soft Drinks'}, 86), ({'Cigarettes', 'Soft Drinks'}, 78), ({'Milk', 'Soft Drinks'}, 84), ({'Gum', 'Toiletries'}, 85), ({'Gum', 'Batteries'}, 93), ({'Gum', 'Candy'}, 95), ({'Magazine', 'Gum'}, 109), ({'Gum', 'Cigarettes'}, 88), ({'Gum', 'Milk'}, 93), ({'Toiletries', 'Batteries'}, 79), ({'Toiletries', 'Candy'}, 99), ({'Magazine', 'Toiletries'}, 85), ({'Toiletries', 'Cigarettes'}, 69), ({'Toiletries', 'Milk'}, 101), ({'Candy', 'Batteries'}, 108), ({'Magazine', 'Batteries'}, 91), ({'Cigarettes', 'Batteries'}, 93), ({'Batteries', 'Milk'}, 100), ({'Magazine', 'Candy'}, 99), ({'Cigarettes', 'Candy'}, 85), ({'Candy', 'Milk'}, 101), ({'Magazine', 'Cigarettes'}, 88), ({'Magazine', 'Milk'}, 98), ({'Cigarettes', 'Milk'}, 92)]
# Association Rules: [({'Energy Drinks'}, {'Gum'}, 0.3485915492957746), ({'Gum'}, {'Energy Drinks'}, 0.32673267326732675), ({'Energy Drinks'}, {'Toiletries'}, 0.3028169014084507), ({'Toiletries'}, {'Energy Drinks'}, 0.30714285714285716), ({'Energy Drinks'}, {'Candy'}, 0.31338028169014087), ({'Energy Drinks'}, {'Cigarettes'}, 0.3345070422535211), ({'Cigarettes'}, {'Energy Drinks'}, 0.3321678321678322), ({'Snacks'}, {'Gum'}, 0.3025830258302583), ({'Snacks'}, {'Candy'}, 0.30996309963099633), ({'Soft Drinks'}, {'Candy'}, 0.3284671532846715), ({'Soft Drinks'}, {'Magazine'}, 0.31386861313868614), ({'Soft Drinks'}, {'Milk'}, 0.30656934306569344), ({'Toiletries'}, {'Gum'}, 0.30357142857142855), ({'Gum'}, {'Batteries'}, 0.3069306930693069), ({'Batteries'}, {'Gum'}, 0.31313131313131315), ({'Gum'}, {'Candy'}, 0.31353135313531355), ({'Magazine'}, {'Gum'}, 0.34276729559748426), ({'Gum'}, {'Magazine'}, 0.35973597359735976), ({'Cigarettes'}, {'Gum'}, 0.3076923076923077), ({'Gum'}, {'Milk'}, 0.3069306930693069), ({'Toiletries'}, {'Candy'}, 0.3535714285714286), ({'Candy'}, {'Toiletries'}, 0.308411214953271), ({'Toiletries'}, {'Magazine'}, 0.30357142857142855), ({'Toiletries'}, {'Milk'}, 0.3607142857142857), ({'Milk'}, {'Toiletries'}, 0.321656050955414), ({'Candy'}, {'Batteries'}, 0.3364485981308411), ({'Batteries'}, {'Candy'}, 0.36363636363636365), ({'Batteries'}, {'Magazine'}, 0.3063973063973064), ({'Cigarettes'}, {'Batteries'}, 0.32517482517482516), ({'Batteries'}, {'Cigarettes'}, 0.31313131313131315), ({'Batteries'}, {'Milk'}, 0.3367003367003367), ({'Milk'}, {'Batteries'}, 0.3184713375796178), ({'Magazine'}, {'Candy'}, 0.3113207547169811), ({'Candy'}, {'Magazine'}, 0.308411214953271), ({'Candy'}, {'Milk'}, 0.3146417445482866), ({'Milk'}, {'Candy'}, 0.321656050955414), ({'Cigarettes'}, {'Magazine'}, 0.3076923076923077), ({'Magazine'}, {'Milk'}, 0.3081761006289308), ({'Milk'}, {'Magazine'}, 0.31210191082802546), ({'Cigarettes'}, {'Milk'}, 0.32167832167832167)]
#
#
# Results for ShopRite:
# Frequent Itemsets: [({'Bread'}, 287), ({'Household Cleaning Products'}, 323), ({'Snacks'}, 304), ({'Meat'}, 303), ({'Dairy'}, 289), ({'Canned Goods'}, 322), ({'Bakery Items'}, 277), ({'Personal Care Products'}, 270), ({'Frozen Foods'}, 314), ({'Vegetables'}, 326), ({'Bread', 'Household Cleaning Products'}, 101), ({'Bread', 'Snacks'}, 95), ({'Bread', 'Meat'}, 78), ({'Dairy', 'Bread'}, 81), ({'Bread', 'Canned Goods'}, 87), ({'Bread', 'Bakery Items'}, 75), ({'Bread', 'Personal Care Products'}, 79), ({'Bread', 'Frozen Foods'}, 91), ({'Bread', 'Vegetables'}, 95), ({'Household Cleaning Products', 'Snacks'}, 108), ({'Household Cleaning Products', 'Meat'}, 97), ({'Dairy', 'Household Cleaning Products'}, 84), ({'Household Cleaning Products', 'Canned Goods'}, 96), ({'Bakery Items', 'Household Cleaning Products'}, 97), ({'Household Cleaning Products', 'Personal Care Products'}, 85), ({'Household Cleaning Products', 'Frozen Foods'}, 100), ({'Vegetables', 'Household Cleaning Products'}, 94), ({'Snacks', 'Meat'}, 84), ({'Dairy', 'Snacks'}, 97), ({'Canned Goods', 'Snacks'}, 87), ({'Bakery Items', 'Snacks'}, 84), ({'Personal Care Products', 'Snacks'}, 81), ({'Frozen Foods', 'Snacks'}, 100), ({'Vegetables', 'Snacks'}, 85), ({'Dairy', 'Meat'}, 87), ({'Canned Goods', 'Meat'}, 91), ({'Bakery Items', 'Meat'}, 76), ({'Personal Care Products', 'Meat'}, 83), ({'Frozen Foods', 'Meat'}, 100), ({'Vegetables', 'Meat'}, 97), ({'Dairy', 'Canned Goods'}, 90), ({'Dairy', 'Bakery Items'}, 87), ({'Dairy', 'Personal Care Products'}, 76), ({'Dairy', 'Frozen Foods'}, 103), ({'Dairy', 'Vegetables'}, 100), ({'Bakery Items', 'Canned Goods'}, 85), ({'Personal Care Products', 'Canned Goods'}, 91), ({'Frozen Foods', 'Canned Goods'}, 107), ({'Vegetables', 'Canned Goods'}, 99), ({'Bakery Items', 'Personal Care Products'}, 70), ({'Bakery Items', 'Frozen Foods'}, 72), ({'Bakery Items', 'Vegetables'}, 88), ({'Frozen Foods', 'Personal Care Products'}, 82), ({'Vegetables', 'Personal Care Products'}, 84), ({'Vegetables', 'Frozen Foods'}, 105)]
# Association Rules: [({'Bread'}, {'Household Cleaning Products'}, 0.3519163763066202), ({'Household Cleaning Products'}, {'Bread'}, 0.3126934984520124), ({'Bread'}, {'Snacks'}, 0.3310104529616725), ({'Snacks'}, {'Bread'}, 0.3125), ({'Bread'}, {'Canned Goods'}, 0.30313588850174217), ({'Bread'}, {'Frozen Foods'}, 0.3170731707317073), ({'Bread'}, {'Vegetables'}, 0.3310104529616725), ({'Household Cleaning Products'}, {'Snacks'}, 0.33436532507739936), ({'Snacks'}, {'Household Cleaning Products'}, 0.35526315789473684), ({'Household Cleaning Products'}, {'Meat'}, 0.30030959752321984), ({'Meat'}, {'Household Cleaning Products'}, 0.3201320132013201), ({'Bakery Items'}, {'Household Cleaning Products'}, 0.35018050541516244), ({'Household Cleaning Products'}, {'Bakery Items'}, 0.30030959752321984), ({'Personal Care Products'}, {'Household Cleaning Products'}, 0.3148148148148148), ({'Household Cleaning Products'}, {'Frozen Foods'}, 0.30959752321981426), ({'Frozen Foods'}, {'Household Cleaning Products'}, 0.3184713375796178), ({'Dairy'}, {'Snacks'}, 0.3356401384083045), ({'Snacks'}, {'Dairy'}, 0.3190789473684211), ({'Bakery Items'}, {'Snacks'}, 0.30324909747292417), ({'Personal Care Products'}, {'Snacks'}, 0.3), ({'Frozen Foods'}, {'Snacks'}, 0.3184713375796178), ({'Snacks'}, {'Frozen Foods'}, 0.32894736842105265), ({'Dairy'}, {'Meat'}, 0.30103806228373703), ({'Meat'}, {'Canned Goods'}, 0.30033003300330036), ({'Personal Care Products'}, {'Meat'}, 0.3074074074074074), ({'Frozen Foods'}, {'Meat'}, 0.3184713375796178), ({'Meat'}, {'Frozen Foods'}, 0.33003300330033003), ({'Meat'}, {'Vegetables'}, 0.3201320132013201), ({'Dairy'}, {'Canned Goods'}, 0.31141868512110726), ({'Dairy'}, {'Bakery Items'}, 0.30103806228373703), ({'Bakery Items'}, {'Dairy'}, 0.3140794223826715), ({'Dairy'}, {'Frozen Foods'}, 0.356401384083045), ({'Frozen Foods'}, {'Dairy'}, 0.32802547770700635), ({'Dairy'}, {'Vegetables'}, 0.3460207612456747), ({'Vegetables'}, {'Dairy'}, 0.3067484662576687), ({'Bakery Items'}, {'Canned Goods'}, 0.30685920577617326), ({'Personal Care Products'}, {'Canned Goods'}, 0.337037037037037), ({'Frozen Foods'}, {'Canned Goods'}, 0.34076433121019106), ({'Canned Goods'}, {'Frozen Foods'}, 0.33229813664596275), ({'Vegetables'}, {'Canned Goods'}, 0.30368098159509205), ({'Canned Goods'}, {'Vegetables'}, 0.30745341614906835), ({'Bakery Items'}, {'Vegetables'}, 0.3176895306859206), ({'Personal Care Products'}, {'Frozen Foods'}, 0.3037037037037037), ({'Personal Care Products'}, {'Vegetables'}, 0.3111111111111111), ({'Vegetables'}, {'Frozen Foods'}, 0.3220858895705521), ({'Frozen Foods'}, {'Vegetables'}, 0.3343949044585987)]
#
#
# Results for K-Mart:
# Frequent Itemsets: [({'Sports Equipment'}, 277), ({'Clothing'}, 306), ({'Toys'}, 289), ({'Pet Supplies'}, 303), ({'Furniture'}, 286), ({'Beauty Products'}, 297), ({'Jewelry'}, 327), ({'Home Appliances'}, 301), ({'Electronics'}, 284), ({'Footwear'}, 328), ({'Sports Equipment', 'Clothing'}, 85), ({'Sports Equipment', 'Toys'}, 83), ({'Sports Equipment', 'Pet Supplies'}, 87), ({'Sports Equipment', 'Furniture'}, 75), ({'Sports Equipment', 'Beauty Products'}, 95), ({'Sports Equipment', 'Jewelry'}, 97), ({'Sports Equipment', 'Home Appliances'}, 85), ({'Sports Equipment', 'Electronics'}, 68), ({'Sports Equipment', 'Footwear'}, 97), ({'Clothing', 'Toys'}, 86), ({'Pet Supplies', 'Clothing'}, 98), ({'Furniture', 'Clothing'}, 91), ({'Clothing', 'Beauty Products'}, 87), ({'Clothing', 'Jewelry'}, 100), ({'Home Appliances', 'Clothing'}, 90), ({'Clothing', 'Electronics'}, 85), ({'Clothing', 'Footwear'}, 91), ({'Pet Supplies', 'Toys'}, 84), ({'Furniture', 'Toys'}, 92), ({'Beauty Products', 'Toys'}, 93), ({'Toys', 'Jewelry'}, 88), ({'Home Appliances', 'Toys'}, 81), ({'Toys', 'Electronics'}, 87), ({'Toys', 'Footwear'}, 89), ({'Pet Supplies', 'Furniture'}, 96), ({'Pet Supplies', 'Beauty Products'}, 93), ({'Pet Supplies', 'Jewelry'}, 102), ({'Pet Supplies', 'Home Appliances'}, 81), ({'Pet Supplies', 'Electronics'}, 76), ({'Pet Supplies', 'Footwear'}, 89), ({'Furniture', 'Beauty Products'}, 85), ({'Furniture', 'Jewelry'}, 97), ({'Furniture', 'Home Appliances'}, 78), ({'Furniture', 'Electronics'}, 80), ({'Furniture', 'Footwear'}, 89), ({'Beauty Products', 'Jewelry'}, 80), ({'Home Appliances', 'Beauty Products'}, 94), ({'Beauty Products', 'Electronics'}, 91), ({'Beauty Products', 'Footwear'}, 88), ({'Home Appliances', 'Jewelry'}, 84), ({'Electronics', 'Jewelry'}, 96), ({'Footwear', 'Jewelry'}, 98), ({'Home Appliances', 'Electronics'}, 84), ({'Home Appliances', 'Footwear'}, 96), ({'Electronics', 'Footwear'}, 92)]
# Association Rules: [({'Sports Equipment'}, {'Clothing'}, 0.30685920577617326), ({'Sports Equipment'}, {'Pet Supplies'}, 0.3140794223826715), ({'Sports Equipment'}, {'Beauty Products'}, 0.34296028880866425), ({'Beauty Products'}, {'Sports Equipment'}, 0.31986531986531985), ({'Sports Equipment'}, {'Jewelry'}, 0.35018050541516244), ({'Sports Equipment'}, {'Home Appliances'}, 0.30685920577617326), ({'Sports Equipment'}, {'Footwear'}, 0.35018050541516244), ({'Pet Supplies'}, {'Clothing'}, 0.3234323432343234), ({'Clothing'}, {'Pet Supplies'}, 0.3202614379084967), ({'Furniture'}, {'Clothing'}, 0.3181818181818182), ({'Clothing'}, {'Jewelry'}, 0.32679738562091504), ({'Jewelry'}, {'Clothing'}, 0.3058103975535168), ({'Furniture'}, {'Toys'}, 0.32167832167832167), ({'Toys'}, {'Furniture'}, 0.31833910034602075), ({'Beauty Products'}, {'Toys'}, 0.31313131313131315), ({'Toys'}, {'Beauty Products'}, 0.3217993079584775), ({'Toys'}, {'Jewelry'}, 0.3044982698961938), ({'Toys'}, {'Electronics'}, 0.30103806228373703), ({'Electronics'}, {'Toys'}, 0.30633802816901406), ({'Toys'}, {'Footwear'}, 0.3079584775086505), ({'Pet Supplies'}, {'Furniture'}, 0.31683168316831684), ({'Furniture'}, {'Pet Supplies'}, 0.3356643356643357), ({'Pet Supplies'}, {'Beauty Products'}, 0.3069306930693069), ({'Beauty Products'}, {'Pet Supplies'}, 0.31313131313131315), ({'Pet Supplies'}, {'Jewelry'}, 0.33663366336633666), ({'Jewelry'}, {'Pet Supplies'}, 0.3119266055045872), ({'Furniture'}, {'Jewelry'}, 0.33916083916083917), ({'Furniture'}, {'Footwear'}, 0.3111888111888112), ({'Home Appliances'}, {'Beauty Products'}, 0.3122923588039867), ({'Beauty Products'}, {'Home Appliances'}, 0.3164983164983165), ({'Beauty Products'}, {'Electronics'}, 0.3063973063973064), ({'Electronics'}, {'Beauty Products'}, 0.3204225352112676), ({'Electronics'}, {'Jewelry'}, 0.3380281690140845), ({'Home Appliances'}, {'Footwear'}, 0.31893687707641194), ({'Electronics'}, {'Footwear'}, 0.323943661971831)]
#
#
# Total Execution Time: 0.08 seconds

# %%
import pandas as pd
from time import time
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Function to load and filter transactions from the dataset
def load_and_filter_transactions(file_path, min_items=2):
    df = pd.read_csv(file_path)
    
    # Use 'Filtered Transaction' as the correct column for transaction data
    transactions = df['Filtered Transaction'].apply(lambda x: x.split(', '))
    
    # Filtering transactions based on the minimum number of items
    filtered_transactions = [tx for tx in transactions if len(tx) >= min_items]
    return filtered_transactions

# Function to analyze transactions and generate frequent itemsets and association rules
def perform_transaction_analysis(file_path, min_support, min_confidence):
    start_time = time()  # Start timer for each analysis

    # Load and filter transactions
    transactions = load_and_filter_transactions(file_path)
    
    # Encoding transactions into a format suitable for Apriori
    encoder = TransactionEncoder()
    transaction_array = encoder.fit(transactions).transform(transactions)
    transaction_df = pd.DataFrame(transaction_array, columns=encoder.columns_)
    
    # Finding frequent itemsets using Apriori algorithm
    frequent_itemsets = apriori(transaction_df, min_support=min_support, use_colnames=True)
    
    # Generating association rules based on the frequent itemsets
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    
    # Print filtered transactions
    print(f"Filtered Transactions from {file_path.split('/')[-1]}:")
    for transaction in transactions:
        print(transaction)
        
    # Print the generated association rules
    print("\nGenerated Association Rules:")
    print(rules[['antecedents', 'consequents', 'support', 'confidence']])
    
    # Print the time taken for each dataset analysis
    print(f"\nTotal Execution Time: {time() - start_time:.2f} seconds\n")

# Main function to handle the execution of transaction analysis
def execute_analysis():
    datasets = {
    'Target': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\target_data_new.csv',
    'Costco': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\costco_data_new.csv',
    '7-Eleven': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\seven_eleven_data.csv',
    'ShopRite': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\shoprite_data.csv',
    'K-Mart': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\kmart_data.csv'
}


    # Display the available datasets to the user
    print("Please select dataset(s):")
    for key, value in datasets.items():
        print(f"{key} - {value.split('/')[-1]}")

    # Accept user input for selected datasets and analysis parameters
    selected_datasets = input("Enter your choices (e.g., Target, 7-Eleven): ").split(',')
    min_support = float(input("Enter minimum support value (e.g., 0.05): "))
    min_confidence = float(input("Enter minimum confidence value (e.g., 0.5): "))

    # Perform analysis on selected datasets
    for dataset in selected_datasets:
        dataset = dataset.strip()  # Remove any leading/trailing spaces
        if dataset in datasets:
            perform_transaction_analysis(datasets[dataset], min_support, min_confidence)
        else:
            print(f"Dataset {dataset} not found. Please check your input.")

# Execute the analysis if the script is run directly
if __name__ == "__main__":
    execute_analysis()
# Out:
# Please select dataset(s):
# Target - target_data_new.csv
# Costco - costco_data_new.csv
# 7-Eleven - seven_eleven_data.csv
# ShopRite - shoprite_data.csv
# K-Mart - kmart_data.csv
# Enter your choices (e.g., Target, 7-Eleven): Target,Shoprite
# Enter minimum support value (e.g., 0.05): 0.05
# Enter minimum confidence value (e.g., 0.5): 0.3
# Filtered Transactions from target_data_new.csv:
# ['Beauty Products', 'Bedding', 'Gardening Supplies', 'Electronics']
# ['Groceries', 'Gardening Supplies', 'Cleaning Supplies', 'Bedding']
# ['Furniture', 'Electronics', 'Groceries', 'Gardening Supplies', 'Bedding']
# ['Furniture', 'Cleaning Supplies', 'Clothes']
# ['Furniture', 'Clothes', 'Bedding', 'Groceries', 'Electronics']
# ['Clothes', 'Gardening Supplies', 'Stationery', 'Toys']
# ['Cleaning Supplies', 'Toys']
# ['Stationery', 'Cleaning Supplies', 'Electronics', 'Gardening Supplies', 'Clothes']
# ['Stationery', 'Groceries']
# ['Groceries', 'Electronics', 'Gardening Supplies', 'Furniture', 'Beauty Products']
# ['Gardening Supplies', 'Furniture', 'Electronics', 'Stationery', 'Groceries']
# ['Electronics', 'Stationery', 'Cleaning Supplies', 'Toys', 'Bedding']
# ['Gardening Supplies', 'Beauty Products', 'Toys']
# ['Groceries', 'Toys', 'Cleaning Supplies', 'Stationery']
# ['Furniture', 'Electronics', 'Toys', 'Beauty Products']
# ['Clothes', 'Cleaning Supplies', 'Toys']
# ['Groceries', 'Gardening Supplies', 'Electronics']
# ['Beauty Products', 'Electronics', 'Toys']
# ['Furniture', 'Groceries', 'Beauty Products', 'Stationery']
# ['Cleaning Supplies', 'Electronics', 'Furniture', 'Groceries', 'Beauty Products']
# ['Bedding', 'Groceries', 'Toys', 'Electronics', 'Stationery']
# ['Furniture', 'Cleaning Supplies', 'Gardening Supplies', 'Electronics']
# ['Cleaning Supplies', 'Stationery', 'Electronics']
# ['Gardening Supplies', 'Toys', 'Clothes', 'Bedding']
# ['Bedding', 'Stationery', 'Groceries', 'Clothes', 'Furniture']
# ['Electronics', 'Clothes', 'Toys', 'Groceries']
# ['Cleaning Supplies', 'Electronics', 'Stationery', 'Gardening Supplies']
# ['Toys', 'Furniture', 'Cleaning Supplies']
# ['Cleaning Supplies', 'Stationery']
# ['Electronics', 'Beauty Products']
# ['Bedding', 'Toys', 'Electronics', 'Groceries']
# ['Stationery', 'Clothes']
# ['Beauty Products', 'Clothes']
# ['Beauty Products', 'Gardening Supplies', 'Cleaning Supplies', 'Furniture', 'Stationery']
# ['Toys', 'Cleaning Supplies', 'Beauty Products', 'Stationery', 'Electronics']
# ['Stationery', 'Electronics', 'Cleaning Supplies', 'Furniture']
# ['Groceries', 'Toys', 'Cleaning Supplies', 'Gardening Supplies']
# ['Gardening Supplies', 'Furniture', 'Groceries', 'Beauty Products', 'Stationery']
# ['Toys', 'Cleaning Supplies', 'Groceries', 'Clothes', 'Stationery']
# ['Cleaning Supplies', 'Electronics', 'Stationery', 'Beauty Products', 'Groceries']
# ['Bedding', 'Gardening Supplies', 'Beauty Products']
# ['Electronics', 'Cleaning Supplies', 'Gardening Supplies']
# ['Gardening Supplies', 'Stationery', 'Toys', 'Furniture']
# ['Toys', 'Clothes', 'Furniture']
# ['Beauty Products', 'Toys', 'Clothes', 'Electronics']
# ['Furniture', 'Stationery', 'Gardening Supplies']
# ['Beauty Products', 'Toys', 'Clothes', 'Electronics', 'Cleaning Supplies']
# ['Gardening Supplies', 'Cleaning Supplies']
# ['Bedding', 'Stationery', 'Groceries', 'Cleaning Supplies']
# ['Groceries', 'Stationery', 'Cleaning Supplies', 'Clothes', 'Gardening Supplies']
# ['Groceries', 'Gardening Supplies', 'Stationery', 'Toys']
# ['Furniture', 'Electronics', 'Gardening Supplies', 'Bedding']
# ['Electronics', 'Cleaning Supplies', 'Toys']
# ['Groceries', 'Furniture', 'Electronics']
# ['Furniture', 'Beauty Products']
# ['Furniture', 'Toys']
# ['Furniture', 'Toys', 'Beauty Products']
# ['Bedding', 'Gardening Supplies', 'Toys', 'Groceries']
# ['Toys', 'Beauty Products', 'Clothes', 'Stationery', 'Furniture']
# ['Electronics', 'Cleaning Supplies', 'Beauty Products']
# ['Gardening Supplies', 'Toys', 'Furniture', 'Cleaning Supplies']
# ['Bedding', 'Groceries', 'Beauty Products']
# ['Electronics', 'Furniture', 'Beauty Products', 'Clothes']
# ['Furniture', 'Cleaning Supplies', 'Bedding', 'Clothes']
# ['Groceries', 'Stationery', 'Beauty Products', 'Bedding', 'Toys']
# ['Groceries', 'Gardening Supplies', 'Clothes', 'Furniture']
# ['Electronics', 'Groceries']
# ['Cleaning Supplies', 'Stationery', 'Gardening Supplies']
# ['Toys', 'Bedding']
# ['Stationery', 'Clothes', 'Groceries', 'Toys']
# ['Electronics', 'Groceries', 'Cleaning Supplies', 'Gardening Supplies']
# ['Electronics', 'Bedding', 'Toys', 'Beauty Products', 'Groceries']
# ['Clothes', 'Beauty Products', 'Bedding']
# ['Toys', 'Bedding', 'Beauty Products', 'Clothes', 'Gardening Supplies']
# ['Beauty Products', 'Electronics']
# ['Electronics', 'Clothes', 'Furniture', 'Stationery', 'Cleaning Supplies']
# ['Groceries', 'Stationery', 'Electronics', 'Furniture']
# ['Cleaning Supplies', 'Beauty Products', 'Bedding', 'Groceries', 'Toys']
# ['Groceries', 'Stationery', 'Toys', 'Electronics', 'Clothes']
# ['Groceries', 'Toys', 'Clothes', 'Gardening Supplies', 'Electronics']
# ['Furniture', 'Electronics', 'Groceries']
# ['Bedding', 'Groceries', 'Beauty Products', 'Toys', 'Electronics']
# ['Beauty Products', 'Stationery', 'Bedding', 'Groceries', 'Gardening Supplies']
# ['Electronics', 'Bedding']
# ['Furniture', 'Toys', 'Electronics']
# ['Cleaning Supplies', 'Electronics']
# ['Gardening Supplies', 'Clothes']
# ['Cleaning Supplies', 'Clothes', 'Furniture', 'Bedding', 'Beauty Products']
# ['Groceries', 'Gardening Supplies', 'Furniture']
# ['Bedding', 'Furniture', 'Groceries', 'Gardening Supplies', 'Clothes']
# ['Cleaning Supplies', 'Stationery', 'Gardening Supplies', 'Beauty Products']
# ['Toys', 'Stationery', 'Bedding']
# ['Furniture', 'Electronics', 'Cleaning Supplies']
# ['Stationery', 'Clothes']
# ['Bedding', 'Furniture', 'Beauty Products', 'Stationery']
# ['Gardening Supplies', 'Beauty Products']
# ['Groceries', 'Toys', 'Gardening Supplies', 'Stationery', 'Cleaning Supplies']
# ['Cleaning Supplies', 'Groceries']
# ['Groceries', 'Electronics', 'Toys', 'Beauty Products']
# ['Cleaning Supplies', 'Groceries', 'Furniture']
# ['Cleaning Supplies', 'Beauty Products', 'Clothes', 'Stationery', 'Bedding']
# ['Electronics', 'Toys', 'Cleaning Supplies', 'Furniture', 'Clothes']
# ['Beauty Products', 'Toys', 'Clothes']
# ['Toys', 'Bedding', 'Clothes', 'Gardening Supplies', 'Stationery']
# ['Clothes', 'Beauty Products', 'Groceries', 'Toys', 'Gardening Supplies']
# ['Furniture', 'Toys', 'Cleaning Supplies']
# ['Stationery', 'Clothes', 'Electronics']
# ['Stationery', 'Toys', 'Beauty Products']
# ['Groceries', 'Stationery']
# ['Electronics', 'Groceries', 'Furniture', 'Cleaning Supplies']
# ['Beauty Products', 'Clothes']
# ['Beauty Products', 'Stationery', 'Bedding', 'Electronics']
# ['Gardening Supplies', 'Furniture']
# ['Electronics', 'Stationery', 'Cleaning Supplies', 'Clothes', 'Beauty Products']
# ['Bedding', 'Clothes', 'Cleaning Supplies', 'Electronics', 'Furniture']
# ['Furniture', 'Clothes', 'Stationery', 'Gardening Supplies', 'Groceries']
# ['Cleaning Supplies', 'Stationery', 'Groceries', 'Electronics', 'Toys']
# ['Groceries', 'Clothes', 'Furniture', 'Toys']
# ['Stationery', 'Clothes', 'Beauty Products', 'Electronics', 'Cleaning Supplies']
# ['Furniture', 'Gardening Supplies', 'Bedding']
# ['Toys', 'Cleaning Supplies', 'Electronics']
# ['Cleaning Supplies', 'Furniture']
# ['Clothes', 'Groceries', 'Stationery', 'Toys', 'Furniture']
# ['Clothes', 'Electronics', 'Groceries']
# ['Gardening Supplies', 'Stationery']
# ['Bedding', 'Electronics']
# ['Groceries', 'Toys']
# ['Groceries', 'Bedding', 'Cleaning Supplies', 'Stationery', 'Toys']
# ['Cleaning Supplies', 'Toys', 'Groceries']
# ['Clothes', 'Gardening Supplies']
# ['Electronics', 'Gardening Supplies', 'Toys', 'Beauty Products']
# ['Toys', 'Gardening Supplies', 'Stationery', 'Clothes', 'Cleaning Supplies']
# ['Gardening Supplies', 'Beauty Products', 'Cleaning Supplies']
# ['Bedding', 'Clothes']
# ['Furniture', 'Electronics', 'Toys', 'Gardening Supplies', 'Beauty Products']
# ['Electronics', 'Groceries', 'Stationery', 'Furniture']
# ['Groceries', 'Gardening Supplies', 'Stationery', 'Beauty Products', 'Toys']
# ['Toys', 'Beauty Products', 'Furniture']
# ['Stationery', 'Groceries', 'Toys']
# ['Electronics', 'Gardening Supplies', 'Bedding']
# ['Clothes', 'Groceries', 'Electronics', 'Toys', 'Furniture']
# ['Stationery', 'Beauty Products', 'Furniture', 'Groceries']
# ['Clothes', 'Cleaning Supplies', 'Gardening Supplies', 'Electronics', 'Furniture']
# ['Gardening Supplies', 'Toys', 'Beauty Products', 'Clothes', 'Cleaning Supplies']
# ['Clothes', 'Electronics', 'Cleaning Supplies']
# ['Groceries', 'Stationery', 'Electronics', 'Toys']
# ['Toys', 'Cleaning Supplies', 'Stationery', 'Electronics']
# ['Stationery', 'Toys', 'Beauty Products']
# ['Electronics', 'Cleaning Supplies', 'Bedding', 'Furniture']
# ['Electronics', 'Clothes', 'Toys', 'Groceries', 'Cleaning Supplies']
# ['Cleaning Supplies', 'Beauty Products']
# ['Cleaning Supplies', 'Bedding', 'Furniture', 'Beauty Products', 'Gardening Supplies']
# ['Electronics', 'Cleaning Supplies', 'Bedding', 'Beauty Products']
# ['Clothes', 'Furniture', 'Toys', 'Cleaning Supplies']
# ['Electronics', 'Clothes', 'Furniture', 'Stationery', 'Gardening Supplies']
# ['Furniture', 'Stationery']
# ['Cleaning Supplies', 'Stationery']
# ['Stationery', 'Clothes', 'Electronics', 'Gardening Supplies', 'Bedding']
# ['Beauty Products', 'Bedding']
# ['Stationery', 'Bedding', 'Toys']
# ['Electronics', 'Clothes', 'Stationery', 'Beauty Products', 'Cleaning Supplies']
# ['Bedding', 'Beauty Products', 'Gardening Supplies', 'Groceries']
# ['Cleaning Supplies', 'Clothes', 'Furniture', 'Bedding']
# ['Gardening Supplies', 'Beauty Products', 'Clothes', 'Electronics']
# ['Cleaning Supplies', 'Stationery', 'Furniture']
# ['Clothes', 'Stationery']
# ['Stationery', 'Beauty Products']
# ['Electronics', 'Bedding', 'Stationery', 'Toys']
# ['Groceries', 'Stationery', 'Gardening Supplies']
# ['Stationery', 'Gardening Supplies', 'Electronics']
# ['Groceries', 'Furniture', 'Electronics', 'Toys', 'Stationery']
# ['Groceries', 'Cleaning Supplies', 'Toys']
# ['Groceries', 'Electronics', 'Cleaning Supplies', 'Stationery']
# ['Clothes', 'Furniture', 'Bedding', 'Electronics']
# ['Groceries', 'Cleaning Supplies', 'Furniture']
# ['Clothes', 'Gardening Supplies', 'Electronics']
# ['Furniture', 'Bedding', 'Gardening Supplies', 'Clothes']
# ['Furniture', 'Toys', 'Groceries']
# ['Stationery', 'Electronics', 'Furniture']
# ['Cleaning Supplies', 'Beauty Products', 'Furniture', 'Stationery']
# ['Gardening Supplies', 'Electronics']
# ['Furniture', 'Stationery', 'Toys', 'Bedding']
# ['Bedding', 'Furniture', 'Toys', 'Electronics', 'Clothes']
# ['Cleaning Supplies', 'Furniture', 'Beauty Products', 'Bedding', 'Groceries']
# ['Groceries', 'Electronics', 'Furniture']
# ['Groceries', 'Gardening Supplies', 'Cleaning Supplies', 'Toys', 'Beauty Products']
# ['Electronics', 'Beauty Products', 'Furniture', 'Gardening Supplies', 'Stationery']
# ['Cleaning Supplies', 'Groceries', 'Electronics']
# ['Gardening Supplies', 'Furniture']
# ['Cleaning Supplies', 'Furniture']
# ['Stationery', 'Electronics', 'Clothes', 'Bedding']
# ['Gardening Supplies', 'Furniture']
# ['Cleaning Supplies', 'Bedding', 'Groceries', 'Electronics', 'Furniture']
# ['Stationery', 'Gardening Supplies', 'Cleaning Supplies', 'Groceries', 'Bedding']
# ['Stationery', 'Toys']
# ['Stationery', 'Furniture', 'Bedding']
# ['Bedding', 'Furniture']
# ['Cleaning Supplies', 'Beauty Products', 'Bedding', 'Clothes', 'Stationery']
# ['Groceries', 'Gardening Supplies']
# ['Bedding', 'Toys', 'Electronics']
# ['Electronics', 'Beauty Products']
# ['Stationery', 'Toys', 'Cleaning Supplies', 'Furniture', 'Groceries']
# ['Electronics', 'Furniture']
# ['Bedding', 'Beauty Products']
# ['Gardening Supplies', 'Groceries', 'Clothes', 'Electronics', 'Furniture']
# ['Beauty Products', 'Furniture', 'Stationery']
# ['Furniture', 'Beauty Products', 'Electronics', 'Toys', 'Stationery']
# ['Electronics', 'Groceries']
# ['Furniture', 'Groceries']
# ['Cleaning Supplies', 'Beauty Products', 'Gardening Supplies', 'Electronics', 'Groceries']
# ['Electronics', 'Clothes']
# ['Bedding', 'Furniture', 'Gardening Supplies', 'Beauty Products']
# ['Clothes', 'Beauty Products', 'Furniture', 'Electronics', 'Gardening Supplies']
# ['Cleaning Supplies', 'Furniture', 'Beauty Products', 'Clothes']
# ['Clothes', 'Bedding']
# ['Electronics', 'Clothes', 'Beauty Products', 'Gardening Supplies']
# ['Gardening Supplies', 'Furniture', 'Clothes', 'Bedding', 'Groceries']
# ['Cleaning Supplies', 'Toys', 'Groceries', 'Electronics', 'Stationery']
# ['Groceries', 'Furniture', 'Clothes']
# ['Furniture', 'Groceries', 'Cleaning Supplies']
# ['Cleaning Supplies', 'Stationery', 'Toys', 'Bedding', 'Furniture']
# ['Groceries', 'Gardening Supplies', 'Toys']
# ['Gardening Supplies', 'Groceries', 'Stationery', 'Furniture', 'Electronics']
# ['Beauty Products', 'Clothes', 'Toys']
# ['Bedding', 'Cleaning Supplies', 'Beauty Products']
# ['Electronics', 'Groceries', 'Beauty Products', 'Stationery', 'Bedding']
# ['Beauty Products', 'Groceries', 'Bedding', 'Cleaning Supplies', 'Electronics']
# ['Electronics', 'Beauty Products', 'Bedding', 'Furniture', 'Gardening Supplies']
# ['Electronics', 'Stationery', 'Beauty Products', 'Bedding', 'Groceries']
# ['Beauty Products', 'Cleaning Supplies']
# ['Toys', 'Clothes', 'Furniture', 'Groceries']
# ['Clothes', 'Stationery', 'Gardening Supplies']
# ['Stationery', 'Clothes', 'Beauty Products', 'Furniture', 'Gardening Supplies']
# ['Beauty Products', 'Clothes', 'Toys']
# ['Electronics', 'Beauty Products', 'Furniture']
# ['Bedding', 'Clothes', 'Stationery', 'Toys', 'Groceries']
# ['Bedding', 'Stationery', 'Cleaning Supplies', 'Furniture', 'Beauty Products']
# ['Bedding', 'Stationery', 'Cleaning Supplies', 'Gardening Supplies']
# ['Cleaning Supplies', 'Toys']
# ['Furniture', 'Toys', 'Electronics']
# ['Groceries', 'Electronics', 'Stationery']
# ['Furniture', 'Gardening Supplies', 'Toys', 'Groceries']
# ['Electronics', 'Cleaning Supplies']
# ['Gardening Supplies', 'Toys', 'Stationery']
# ['Electronics', 'Toys', 'Beauty Products']
# ['Furniture', 'Groceries', 'Stationery']
# ['Furniture', 'Groceries', 'Electronics', 'Bedding']
# ['Stationery', 'Cleaning Supplies', 'Gardening Supplies']
# ['Gardening Supplies', 'Clothes', 'Toys', 'Cleaning Supplies']
# ['Beauty Products', 'Furniture', 'Gardening Supplies', 'Groceries', 'Bedding']
# ['Electronics', 'Groceries', 'Beauty Products', 'Clothes', 'Bedding']
# ['Electronics', 'Beauty Products', 'Groceries', 'Stationery', 'Cleaning Supplies']
# ['Bedding', 'Beauty Products']
# ['Beauty Products', 'Groceries', 'Electronics', 'Clothes', 'Gardening Supplies']
# ['Clothes', 'Gardening Supplies', 'Groceries', 'Electronics', 'Beauty Products']
# ['Stationery', 'Clothes', 'Bedding']
# ['Beauty Products', 'Stationery']
# ['Bedding', 'Clothes', 'Gardening Supplies', 'Stationery']
# ['Cleaning Supplies', 'Clothes']
# ['Clothes', 'Cleaning Supplies', 'Bedding']
# ['Clothes', 'Stationery']
# ['Toys', 'Stationery']
# ['Toys', 'Electronics', 'Gardening Supplies', 'Stationery']
# ['Electronics', 'Bedding']
# ['Clothes', 'Furniture', 'Electronics', 'Stationery']
# ['Electronics', 'Gardening Supplies']
# ['Cleaning Supplies', 'Electronics']
# ['Stationery', 'Clothes', 'Furniture', 'Gardening Supplies', 'Groceries']
# ['Electronics', 'Toys', 'Groceries', 'Furniture']
# ['Beauty Products', 'Groceries', 'Toys', 'Gardening Supplies']
# ['Electronics', 'Bedding']
# ['Toys', 'Cleaning Supplies', 'Furniture', 'Clothes', 'Groceries']
# ['Clothes', 'Bedding']
# ['Furniture', 'Bedding', 'Gardening Supplies']
# ['Stationery', 'Furniture']
# ['Electronics', 'Stationery', 'Beauty Products']
# ['Clothes', 'Beauty Products']
# ['Toys', 'Groceries']
# ['Gardening Supplies', 'Clothes', 'Furniture', 'Cleaning Supplies']
# ['Beauty Products', 'Gardening Supplies', 'Cleaning Supplies', 'Groceries', 'Electronics']
# ['Gardening Supplies', 'Stationery', 'Toys', 'Bedding']
# ['Groceries', 'Clothes', 'Electronics', 'Toys', 'Gardening Supplies']
# ['Stationery', 'Groceries', 'Beauty Products', 'Clothes', 'Bedding']
# ['Clothes', 'Cleaning Supplies', 'Electronics']
# ['Groceries', 'Furniture', 'Bedding', 'Clothes', 'Stationery']
# ['Groceries', 'Furniture', 'Bedding']
# ['Gardening Supplies', 'Bedding', 'Groceries', 'Cleaning Supplies']
# ['Clothes', 'Stationery', 'Cleaning Supplies', 'Electronics']
# ['Toys', 'Beauty Products']
# ['Groceries', 'Furniture', 'Toys', 'Gardening Supplies']
# ['Electronics', 'Beauty Products', 'Gardening Supplies', 'Furniture', 'Cleaning Supplies']
# ['Cleaning Supplies', 'Clothes', 'Furniture', 'Gardening Supplies', 'Electronics']
# ['Cleaning Supplies', 'Stationery']
# ['Groceries', 'Cleaning Supplies', 'Furniture', 'Electronics']
# ['Toys', 'Gardening Supplies']
# ['Cleaning Supplies', 'Clothes', 'Electronics']
# ['Groceries', 'Bedding']
# ['Toys', 'Electronics', 'Furniture', 'Bedding', 'Stationery']
# ['Cleaning Supplies', 'Bedding', 'Groceries', 'Stationery']
# ['Electronics', 'Clothes', 'Stationery', 'Groceries']
# ['Clothes', 'Gardening Supplies', 'Stationery', 'Beauty Products']
# ['Beauty Products', 'Cleaning Supplies', 'Clothes']
# ['Stationery', 'Electronics', 'Gardening Supplies']
# ['Groceries', 'Electronics']
# ['Clothes', 'Toys']
# ['Clothes', 'Gardening Supplies']
# ['Electronics', 'Bedding', 'Toys']
# ['Beauty Products', 'Furniture', 'Clothes']
# ['Electronics', 'Bedding', 'Stationery']
# ['Toys', 'Clothes', 'Beauty Products', 'Electronics', 'Stationery']
# ['Stationery', 'Clothes', 'Beauty Products']
# ['Toys', 'Stationery', 'Cleaning Supplies', 'Bedding']
# ['Furniture', 'Cleaning Supplies']
# ['Bedding', 'Gardening Supplies', 'Groceries', 'Furniture', 'Toys']
# ['Stationery', 'Cleaning Supplies', 'Clothes', 'Electronics']
# ['Clothes', 'Stationery', 'Cleaning Supplies', 'Gardening Supplies']
# ['Clothes', 'Cleaning Supplies', 'Groceries', 'Gardening Supplies', 'Furniture']
# ['Toys', 'Beauty Products', 'Cleaning Supplies', 'Furniture', 'Stationery']
# ['Beauty Products', 'Gardening Supplies', 'Bedding']
# ['Furniture', 'Cleaning Supplies', 'Stationery', 'Gardening Supplies']
# ['Electronics', 'Bedding', 'Furniture', 'Stationery']
# ['Bedding', 'Clothes', 'Toys']
# ['Electronics', 'Furniture', 'Beauty Products']
# ['Clothes', 'Stationery', 'Groceries', 'Cleaning Supplies', 'Beauty Products']
# ['Gardening Supplies', 'Beauty Products', 'Toys', 'Clothes', 'Groceries']
# ['Gardening Supplies', 'Toys', 'Electronics']
# ['Toys', 'Gardening Supplies']
# ['Cleaning Supplies', 'Clothes', 'Gardening Supplies']
# ['Clothes', 'Electronics', 'Cleaning Supplies', 'Gardening Supplies']
# ['Beauty Products', 'Stationery', 'Furniture', 'Cleaning Supplies']
# ['Furniture', 'Gardening Supplies', 'Cleaning Supplies', 'Stationery']
# ['Electronics', 'Cleaning Supplies', 'Beauty Products']
# ['Groceries', 'Clothes', 'Toys']
# ['Beauty Products', 'Furniture', 'Gardening Supplies', 'Groceries']
# ['Clothes', 'Electronics', 'Stationery', 'Furniture']
# ['Cleaning Supplies', 'Furniture', 'Stationery', 'Electronics']
# ['Gardening Supplies', 'Electronics', 'Bedding', 'Cleaning Supplies']
# ['Furniture', 'Cleaning Supplies', 'Bedding', 'Stationery']
# ['Toys', 'Cleaning Supplies', 'Beauty Products', 'Gardening Supplies', 'Furniture']
# ['Beauty Products', 'Electronics', 'Gardening Supplies']
# ['Beauty Products', 'Toys', 'Stationery']
# ['Electronics', 'Stationery', 'Bedding', 'Furniture', 'Beauty Products']
# ['Furniture', 'Bedding', 'Electronics']
# ['Cleaning Supplies', 'Stationery', 'Gardening Supplies', 'Furniture']
# ['Furniture', 'Electronics', 'Groceries']
# ['Toys', 'Furniture', 'Beauty Products', 'Stationery', 'Electronics']
# ['Stationery', 'Toys']
# ['Beauty Products', 'Cleaning Supplies']
# ['Stationery', 'Bedding']
# ['Clothes', 'Beauty Products', 'Furniture', 'Toys', 'Gardening Supplies']
# ['Toys', 'Cleaning Supplies', 'Stationery', 'Bedding']
# ['Clothes', 'Gardening Supplies', 'Cleaning Supplies', 'Furniture', 'Groceries']
# ['Cleaning Supplies', 'Bedding', 'Electronics', 'Beauty Products']
# ['Furniture', 'Toys']
# ['Groceries', 'Toys']
# ['Toys', 'Beauty Products', 'Bedding', 'Electronics']
# ['Groceries', 'Clothes']
# ['Bedding', 'Cleaning Supplies']
# ['Bedding', 'Groceries', 'Toys', 'Clothes', 'Electronics']
# ['Bedding', 'Gardening Supplies']
# ['Bedding', 'Clothes', 'Toys']
# ['Electronics', 'Gardening Supplies', 'Furniture', 'Beauty Products']
# ['Furniture', 'Clothes', 'Cleaning Supplies']
# ['Gardening Supplies', 'Cleaning Supplies', 'Groceries', 'Clothes', 'Furniture']
# ['Bedding', 'Electronics', 'Clothes', 'Groceries']
# ['Gardening Supplies', 'Clothes', 'Groceries']
# ['Clothes', 'Toys']
# ['Beauty Products', 'Bedding', 'Furniture', 'Gardening Supplies', 'Stationery']
# ['Gardening Supplies', 'Stationery', 'Beauty Products', 'Cleaning Supplies']
# ['Bedding', 'Groceries']
# ['Toys', 'Bedding', 'Furniture', 'Cleaning Supplies']
# ['Bedding', 'Gardening Supplies', 'Stationery', 'Furniture']
# ['Gardening Supplies', 'Furniture', 'Groceries', 'Cleaning Supplies', 'Stationery']
# ['Gardening Supplies', 'Furniture', 'Groceries', 'Cleaning Supplies']
# ['Clothes', 'Toys', 'Electronics', 'Bedding', 'Groceries']
# ['Stationery', 'Toys', 'Furniture', 'Bedding']
# ['Beauty Products', 'Toys', 'Electronics', 'Bedding']
# ['Bedding', 'Clothes', 'Beauty Products']
# ['Furniture', 'Cleaning Supplies', 'Clothes', 'Beauty Products', 'Groceries']
# ['Clothes', 'Bedding', 'Stationery']
# ['Beauty Products', 'Cleaning Supplies', 'Bedding', 'Groceries']
# ['Clothes', 'Electronics', 'Gardening Supplies', 'Beauty Products']
# ['Gardening Supplies', 'Clothes']
# ['Cleaning Supplies', 'Beauty Products', 'Furniture', 'Groceries', 'Electronics']
# ['Toys', 'Gardening Supplies', 'Beauty Products', 'Groceries', 'Stationery']
# ['Stationery', 'Electronics', 'Toys', 'Beauty Products', 'Cleaning Supplies']
# ['Beauty Products', 'Bedding', 'Furniture', 'Gardening Supplies', 'Groceries']
# ['Electronics', 'Bedding', 'Stationery', 'Furniture']
# ['Beauty Products', 'Clothes', 'Bedding', 'Stationery', 'Toys']
# ['Electronics', 'Clothes', 'Stationery', 'Bedding']
# ['Clothes', 'Stationery']
# ['Stationery', 'Clothes', 'Gardening Supplies', 'Bedding']
# ['Stationery', 'Toys', 'Furniture', 'Groceries']
# ['Cleaning Supplies', 'Bedding', 'Stationery', 'Gardening Supplies']
# ['Toys', 'Groceries', 'Clothes', 'Stationery', 'Cleaning Supplies']
# ['Cleaning Supplies', 'Groceries']
# ['Groceries', 'Stationery', 'Beauty Products', 'Clothes', 'Bedding']
# ['Groceries', 'Beauty Products', 'Clothes', 'Cleaning Supplies']
# ['Electronics', 'Cleaning Supplies', 'Bedding']
# ['Toys', 'Beauty Products']
# ['Stationery', 'Toys']
# ['Furniture', 'Gardening Supplies', 'Stationery', 'Electronics']
# ['Bedding', 'Stationery', 'Groceries']
# ['Beauty Products', 'Furniture']
# ['Furniture', 'Toys', 'Cleaning Supplies']
# ['Furniture', 'Cleaning Supplies', 'Gardening Supplies', 'Stationery', 'Toys']
# ['Stationery', 'Bedding', 'Gardening Supplies', 'Electronics', 'Clothes']
# ['Groceries', 'Beauty Products', 'Cleaning Supplies', 'Toys']
# ['Electronics', 'Groceries', 'Furniture', 'Toys']
# ['Bedding', 'Beauty Products']
# ['Bedding', 'Stationery', 'Clothes']
# ['Toys', 'Gardening Supplies', 'Electronics']
# ['Bedding', 'Toys']
# ['Gardening Supplies', 'Toys', 'Electronics']
# ['Clothes', 'Groceries']
# ['Beauty Products', 'Stationery', 'Electronics']
# ['Clothes', 'Cleaning Supplies']
# ['Stationery', 'Bedding']
# ['Furniture', 'Bedding', 'Beauty Products', 'Stationery', 'Electronics']
# ['Beauty Products', 'Furniture', 'Bedding']
# ['Toys', 'Beauty Products', 'Stationery', 'Furniture', 'Gardening Supplies']
# ['Clothes', 'Beauty Products', 'Furniture']
# ['Bedding', 'Groceries', 'Stationery', 'Toys', 'Electronics']
# ['Cleaning Supplies', 'Bedding', 'Electronics', 'Groceries']
# ['Cleaning Supplies', 'Gardening Supplies', 'Clothes', 'Bedding', 'Electronics']
# ['Toys', 'Clothes']
# ['Toys', 'Bedding']
# ['Groceries', 'Furniture', 'Beauty Products']
# ['Electronics', 'Toys', 'Stationery', 'Beauty Products']
# ['Toys', 'Stationery', 'Furniture']
# ['Groceries', 'Beauty Products', 'Stationery', 'Bedding']
# ['Stationery', 'Groceries']
# ['Cleaning Supplies', 'Toys', 'Clothes', 'Electronics']
# ['Electronics', 'Toys', 'Beauty Products']
# ['Bedding', 'Toys']
# ['Cleaning Supplies', 'Stationery', 'Gardening Supplies']
# ['Toys', 'Gardening Supplies']
# ['Beauty Products', 'Stationery', 'Clothes']
# ['Stationery', 'Toys', 'Gardening Supplies', 'Cleaning Supplies']
# ['Bedding', 'Beauty Products', 'Gardening Supplies', 'Clothes', 'Cleaning Supplies']
# ['Groceries', 'Stationery', 'Cleaning Supplies', 'Furniture', 'Beauty Products']
# ['Furniture', 'Stationery', 'Electronics', 'Bedding']
# ['Groceries', 'Toys', 'Cleaning Supplies', 'Electronics']
# ['Stationery', 'Furniture', 'Beauty Products', 'Toys']
# ['Gardening Supplies', 'Electronics', 'Cleaning Supplies', 'Groceries']
# ['Toys', 'Furniture', 'Groceries', 'Gardening Supplies']
# ['Gardening Supplies', 'Stationery', 'Electronics', 'Furniture', 'Bedding']
# ['Bedding', 'Clothes']
# ['Cleaning Supplies', 'Beauty Products', 'Stationery', 'Furniture']
# ['Beauty Products', 'Electronics', 'Bedding', 'Stationery']
# ['Beauty Products', 'Electronics', 'Gardening Supplies']
# ['Beauty Products', 'Electronics', 'Furniture']
# ['Furniture', 'Electronics']
# ['Furniture', 'Electronics', 'Clothes']
# ['Clothes', 'Toys', 'Bedding', 'Furniture', 'Electronics']
# ['Cleaning Supplies', 'Beauty Products', 'Gardening Supplies', 'Stationery']
# ['Furniture', 'Stationery']
# ['Cleaning Supplies', 'Toys', 'Clothes', 'Beauty Products']
# ['Toys', 'Gardening Supplies', 'Electronics', 'Clothes', 'Bedding']
# ['Clothes', 'Cleaning Supplies', 'Stationery']
# ['Gardening Supplies', 'Cleaning Supplies', 'Bedding', 'Electronics']
# ['Clothes', 'Beauty Products', 'Bedding', 'Stationery']
# ['Cleaning Supplies', 'Electronics', 'Bedding', 'Groceries', 'Furniture']
# ['Stationery', 'Clothes', 'Furniture']
# ['Beauty Products', 'Toys']
# ['Furniture', 'Gardening Supplies', 'Beauty Products', 'Bedding']
# ['Electronics', 'Clothes', 'Stationery', 'Furniture']
# ['Stationery', 'Toys', 'Groceries', 'Furniture', 'Cleaning Supplies']
# ['Stationery', 'Clothes', 'Bedding', 'Cleaning Supplies', 'Beauty Products']
# ['Beauty Products', 'Clothes']
# ['Gardening Supplies', 'Beauty Products', 'Cleaning Supplies']
# ['Toys', 'Clothes', 'Cleaning Supplies', 'Stationery']
# ['Groceries', 'Furniture', 'Toys', 'Cleaning Supplies', 'Stationery']
# ['Cleaning Supplies', 'Electronics']
# ['Stationery', 'Bedding', 'Furniture', 'Groceries']
# ['Beauty Products', 'Groceries', 'Furniture']
# ['Gardening Supplies', 'Bedding', 'Toys', 'Stationery']
# ['Toys', 'Groceries', 'Bedding', 'Beauty Products']
# ['Furniture', 'Groceries', 'Bedding', 'Electronics', 'Cleaning Supplies']
# ['Stationery', 'Electronics', 'Clothes', 'Toys']
# ['Gardening Supplies', 'Stationery']
# ['Furniture', 'Groceries', 'Toys', 'Beauty Products', 'Stationery']
# ['Bedding', 'Toys', 'Beauty Products', 'Gardening Supplies', 'Clothes']
# ['Clothes', 'Stationery', 'Electronics', 'Bedding']
# ['Cleaning Supplies', 'Toys', 'Clothes', 'Electronics']
# ['Cleaning Supplies', 'Toys', 'Beauty Products', 'Bedding']
# ['Furniture', 'Cleaning Supplies', 'Toys', 'Clothes', 'Beauty Products']
# ['Stationery', 'Electronics', 'Furniture', 'Cleaning Supplies', 'Toys']
# ['Bedding', 'Groceries']
# ['Groceries', 'Furniture', 'Electronics', 'Bedding', 'Toys']
# ['Cleaning Supplies', 'Furniture', 'Groceries', 'Gardening Supplies']
# ['Beauty Products', 'Clothes', 'Gardening Supplies']
# ['Toys', 'Groceries', 'Cleaning Supplies', 'Stationery']
# ['Toys', 'Electronics']
# ['Bedding', 'Gardening Supplies']
# ['Groceries', 'Gardening Supplies']
# ['Electronics', 'Stationery']
# ['Stationery', 'Toys', 'Cleaning Supplies', 'Furniture', 'Clothes']
# ['Toys', 'Gardening Supplies', 'Electronics', 'Beauty Products', 'Bedding']
# ['Stationery', 'Beauty Products', 'Toys', 'Furniture', 'Electronics']
# ['Clothes', 'Groceries']
# ['Gardening Supplies', 'Toys', 'Stationery']
# ['Electronics', 'Cleaning Supplies']
# ['Gardening Supplies', 'Stationery', 'Clothes', 'Beauty Products', 'Cleaning Supplies']
# ['Groceries', 'Bedding', 'Stationery', 'Electronics', 'Cleaning Supplies']
# ['Electronics', 'Stationery', 'Gardening Supplies', 'Bedding', 'Toys']
# ['Beauty Products', 'Furniture', 'Gardening Supplies', 'Bedding', 'Groceries']
# ['Groceries', 'Bedding', 'Beauty Products', 'Cleaning Supplies']
# ['Cleaning Supplies', 'Stationery']
# ['Cleaning Supplies', 'Stationery', 'Gardening Supplies', 'Clothes']
# ['Furniture', 'Toys', 'Bedding', 'Beauty Products', 'Stationery']
# ['Stationery', 'Bedding']
# ['Stationery', 'Groceries']
# ['Furniture', 'Clothes', 'Bedding', 'Toys', 'Cleaning Supplies']
# ['Toys', 'Electronics']
# ['Clothes', 'Toys']
# ['Gardening Supplies', 'Beauty Products', 'Stationery', 'Electronics']
# ['Groceries', 'Gardening Supplies']
# ['Stationery', 'Cleaning Supplies', 'Furniture']
# ['Bedding', 'Cleaning Supplies']
# ['Gardening Supplies', 'Stationery', 'Groceries', 'Electronics']
# ['Furniture', 'Beauty Products']
# ['Furniture', 'Clothes']
# ['Clothes', 'Bedding', 'Furniture', 'Groceries', 'Electronics']
# ['Stationery', 'Clothes', 'Gardening Supplies', 'Groceries', 'Bedding']
# ['Groceries', 'Beauty Products', 'Furniture']
# ['Stationery', 'Gardening Supplies']
# ['Cleaning Supplies', 'Groceries', 'Toys', 'Clothes', 'Beauty Products']
# ['Groceries', 'Cleaning Supplies', 'Bedding', 'Beauty Products']
# ['Groceries', 'Bedding', 'Gardening Supplies']
# ['Stationery', 'Bedding']
# ['Groceries', 'Cleaning Supplies']
# ['Beauty Products', 'Stationery']
# ['Cleaning Supplies', 'Bedding', 'Stationery']
# ['Stationery', 'Clothes', 'Electronics', 'Cleaning Supplies', 'Toys']
# ['Beauty Products', 'Stationery', 'Gardening Supplies']
# ['Beauty Products', 'Cleaning Supplies', 'Stationery', 'Furniture']
# ['Stationery', 'Groceries', 'Bedding']
# ['Toys', 'Beauty Products', 'Groceries', 'Clothes']
# ['Clothes', 'Bedding', 'Toys']
# ['Electronics', 'Groceries']
# ['Electronics', 'Gardening Supplies', 'Groceries']
# ['Furniture', 'Beauty Products', 'Bedding', 'Gardening Supplies', 'Electronics']
# ['Bedding', 'Gardening Supplies', 'Groceries', 'Furniture', 'Cleaning Supplies']
# ['Gardening Supplies', 'Clothes', 'Stationery']
# ['Stationery', 'Electronics', 'Gardening Supplies', 'Cleaning Supplies']
# ['Beauty Products', 'Furniture', 'Toys']
# ['Stationery', 'Cleaning Supplies', 'Beauty Products', 'Groceries', 'Bedding']
# ['Stationery', 'Furniture']
# ['Furniture', 'Toys']
# ['Beauty Products', 'Groceries', 'Cleaning Supplies', 'Stationery', 'Furniture']
# ['Clothes', 'Electronics']
# ['Clothes', 'Cleaning Supplies', 'Furniture', 'Bedding']
# ['Bedding', 'Beauty Products', 'Stationery']
# ['Electronics', 'Furniture', 'Beauty Products']
# ['Toys', 'Gardening Supplies', 'Electronics']
# ['Electronics', 'Toys', 'Clothes']
# ['Toys', 'Gardening Supplies', 'Cleaning Supplies', 'Furniture', 'Bedding']
# ['Bedding', 'Gardening Supplies']
# ['Stationery', 'Cleaning Supplies']
# ['Cleaning Supplies', 'Bedding']
# ['Groceries', 'Cleaning Supplies', 'Furniture']
# ['Groceries', 'Furniture', 'Clothes']
# ['Electronics', 'Furniture', 'Gardening Supplies']
# ['Toys', 'Groceries', 'Bedding']
# ['Toys', 'Furniture', 'Cleaning Supplies', 'Clothes']
# ['Furniture', 'Clothes', 'Bedding']
# ['Groceries', 'Beauty Products', 'Electronics']
# ['Bedding', 'Electronics', 'Groceries', 'Gardening Supplies', 'Cleaning Supplies']
# ['Clothes', 'Furniture', 'Gardening Supplies', 'Cleaning Supplies']
# ['Bedding', 'Clothes']
# ['Groceries', 'Electronics', 'Clothes']
# ['Beauty Products', 'Cleaning Supplies', 'Furniture', 'Toys']
# ['Cleaning Supplies', 'Clothes', 'Gardening Supplies', 'Furniture']
# ['Cleaning Supplies', 'Beauty Products', 'Groceries']
# ['Groceries', 'Clothes', 'Stationery', 'Beauty Products', 'Furniture']
# ['Gardening Supplies', 'Furniture', 'Toys', 'Electronics', 'Beauty Products']
# ['Clothes', 'Bedding', 'Gardening Supplies', 'Stationery']
# ['Beauty Products', 'Gardening Supplies', 'Furniture', 'Bedding', 'Cleaning Supplies']
# ['Beauty Products', 'Cleaning Supplies', 'Bedding']
# ['Furniture', 'Gardening Supplies']
# ['Furniture', 'Cleaning Supplies']
# ['Beauty Products', 'Electronics', 'Stationery']
# ['Gardening Supplies', 'Furniture', 'Cleaning Supplies']
# ['Bedding', 'Cleaning Supplies', 'Clothes']
# ['Clothes', 'Furniture', 'Gardening Supplies', 'Stationery']
# ['Toys', 'Gardening Supplies', 'Cleaning Supplies', 'Bedding']
# ['Toys', 'Beauty Products', 'Clothes', 'Bedding']
# ['Beauty Products', 'Bedding']
# ['Beauty Products', 'Electronics', 'Furniture']
# ['Electronics', 'Stationery', 'Bedding']
# ['Cleaning Supplies', 'Beauty Products', 'Clothes', 'Bedding', 'Furniture']
# ['Electronics', 'Stationery', 'Bedding', 'Toys']
# ['Stationery', 'Toys', 'Furniture', 'Gardening Supplies', 'Clothes']
# ['Stationery', 'Cleaning Supplies', 'Groceries', 'Clothes', 'Bedding']
# ['Clothes', 'Beauty Products']
# ['Toys', 'Clothes', 'Furniture']
# ['Toys', 'Gardening Supplies', 'Electronics']
# ['Stationery', 'Toys']
# ['Clothes', 'Stationery', 'Furniture', 'Bedding']
# ['Bedding', 'Cleaning Supplies']
# ['Bedding', 'Beauty Products']
# ['Groceries', 'Clothes', 'Gardening Supplies']
# ['Toys', 'Electronics']
# ['Groceries', 'Cleaning Supplies', 'Bedding', 'Clothes', 'Beauty Products']
# ['Bedding', 'Electronics', 'Cleaning Supplies', 'Groceries', 'Clothes']
# ['Groceries', 'Cleaning Supplies', 'Stationery']
# ['Cleaning Supplies', 'Furniture', 'Groceries']
# ['Electronics', 'Furniture']
# ['Groceries', 'Electronics', 'Stationery']
# ['Groceries', 'Electronics', 'Beauty Products', 'Bedding']
# ['Furniture', 'Clothes']
# ['Cleaning Supplies', 'Electronics', 'Gardening Supplies', 'Groceries', 'Beauty Products']
# ['Gardening Supplies', 'Toys', 'Stationery', 'Beauty Products']
# ['Bedding', 'Electronics']
# ['Stationery', 'Clothes']
# ['Gardening Supplies', 'Toys', 'Bedding']
# ['Cleaning Supplies', 'Bedding', 'Beauty Products', 'Gardening Supplies']
# ['Furniture', 'Groceries', 'Stationery']
# ['Toys', 'Clothes', 'Beauty Products']
# ['Beauty Products', 'Furniture']
# ['Groceries', 'Cleaning Supplies', 'Electronics', 'Gardening Supplies']
# ['Stationery', 'Bedding', 'Electronics']
# ['Cleaning Supplies', 'Electronics', 'Groceries']
# ['Cleaning Supplies', 'Toys', 'Electronics', 'Bedding']
# ['Clothes', 'Beauty Products', 'Stationery']
# ['Groceries', 'Stationery', 'Furniture', 'Beauty Products', 'Bedding']
# ['Groceries', 'Bedding', 'Beauty Products']
# ['Bedding', 'Stationery', 'Groceries']
# ['Furniture', 'Clothes', 'Cleaning Supplies']
# ['Clothes', 'Groceries', 'Gardening Supplies']
# ['Clothes', 'Gardening Supplies', 'Electronics', 'Furniture', 'Cleaning Supplies']
# ['Toys', 'Furniture', 'Beauty Products', 'Bedding']
# ['Clothes', 'Stationery', 'Gardening Supplies', 'Beauty Products']
# ['Cleaning Supplies', 'Gardening Supplies', 'Clothes', 'Electronics', 'Bedding']
# ['Electronics', 'Groceries', 'Stationery', 'Beauty Products']
# ['Beauty Products', 'Toys']
# ['Clothes', 'Gardening Supplies', 'Cleaning Supplies', 'Bedding', 'Furniture']
# ['Bedding', 'Beauty Products', 'Electronics', 'Furniture']
# ['Stationery', 'Bedding', 'Furniture', 'Electronics']
# ['Cleaning Supplies', 'Beauty Products', 'Toys']
# ['Beauty Products', 'Gardening Supplies', 'Bedding', 'Cleaning Supplies']
# ['Stationery', 'Electronics', 'Clothes', 'Gardening Supplies']
# ['Toys', 'Furniture', 'Gardening Supplies', 'Groceries', 'Bedding']
# ['Cleaning Supplies', 'Electronics', 'Beauty Products', 'Toys']
# ['Groceries', 'Cleaning Supplies', 'Bedding', 'Gardening Supplies', 'Electronics']
# ['Beauty Products', 'Clothes', 'Stationery']
# ['Groceries', 'Clothes']
# ['Groceries', 'Bedding']
# ['Furniture', 'Gardening Supplies', 'Groceries', 'Clothes']
# ['Electronics', 'Toys']
# ['Stationery', 'Electronics']
# ['Electronics', 'Beauty Products', 'Stationery']
# ['Clothes', 'Beauty Products', 'Groceries']
# ['Furniture', 'Cleaning Supplies']
# ['Stationery', 'Cleaning Supplies']
# ['Gardening Supplies', 'Cleaning Supplies', 'Clothes', 'Stationery', 'Beauty Products']
# ['Gardening Supplies', 'Beauty Products']
# ['Stationery', 'Gardening Supplies', 'Electronics', 'Groceries', 'Toys']
# ['Bedding', 'Stationery']
# ['Clothes', 'Bedding', 'Stationery']
# ['Electronics', 'Clothes', 'Furniture', 'Toys', 'Gardening Supplies']
# ['Electronics', 'Beauty Products', 'Cleaning Supplies', 'Gardening Supplies']
# ['Groceries', 'Electronics', 'Bedding']
# ['Beauty Products', 'Bedding', 'Electronics', 'Groceries']
# ['Furniture', 'Clothes']
# ['Gardening Supplies', 'Cleaning Supplies', 'Bedding', 'Beauty Products']
# ['Groceries', 'Clothes', 'Electronics', 'Beauty Products', 'Cleaning Supplies']
# ['Gardening Supplies', 'Stationery', 'Bedding']
# ['Cleaning Supplies', 'Toys', 'Electronics', 'Bedding']
# ['Cleaning Supplies', 'Toys', 'Clothes']
# ['Stationery', 'Toys', 'Electronics', 'Clothes', 'Groceries']
# ['Groceries', 'Toys']
# ['Gardening Supplies', 'Stationery']
# ['Cleaning Supplies', 'Stationery', 'Gardening Supplies']
# ['Beauty Products', 'Gardening Supplies', 'Stationery']
# ['Groceries', 'Clothes', 'Gardening Supplies', 'Bedding', 'Furniture']
# ['Cleaning Supplies', 'Furniture', 'Stationery', 'Beauty Products']
# ['Cleaning Supplies', 'Electronics', 'Beauty Products', 'Toys', 'Groceries']
# ['Stationery', 'Clothes', 'Furniture']
# ['Groceries', 'Beauty Products']
# ['Furniture', 'Gardening Supplies', 'Groceries', 'Cleaning Supplies']
# ['Stationery', 'Cleaning Supplies', 'Clothes', 'Toys', 'Gardening Supplies']
# ['Cleaning Supplies', 'Clothes', 'Furniture', 'Groceries']
# ['Toys', 'Stationery', 'Beauty Products']
# ['Stationery', 'Bedding']
# ['Electronics', 'Bedding', 'Cleaning Supplies']
# ['Furniture', 'Toys', 'Electronics', 'Gardening Supplies', 'Bedding']
# ['Electronics', 'Cleaning Supplies', 'Stationery']
# ['Stationery', 'Electronics', 'Beauty Products']
# ['Stationery', 'Gardening Supplies']
# ['Beauty Products', 'Furniture', 'Stationery']
# ['Cleaning Supplies', 'Bedding', 'Electronics', 'Furniture']
# ['Beauty Products', 'Groceries']
# ['Stationery', 'Electronics', 'Toys', 'Bedding']
# ['Electronics', 'Toys']
# ['Furniture', 'Groceries', 'Cleaning Supplies']
# ['Clothes', 'Bedding', 'Furniture']
# ['Clothes', 'Stationery', 'Bedding', 'Furniture']
# ['Cleaning Supplies', 'Groceries', 'Electronics']
# ['Cleaning Supplies', 'Electronics', 'Clothes', 'Gardening Supplies', 'Beauty Products']
# ['Bedding', 'Clothes']
# ['Cleaning Supplies', 'Bedding', 'Gardening Supplies']
# ['Bedding', 'Toys', 'Furniture', 'Beauty Products']
# ['Gardening Supplies', 'Groceries', 'Clothes', 'Furniture', 'Electronics']
# ['Furniture', 'Toys']
# ['Electronics', 'Beauty Products', 'Gardening Supplies']
# ['Electronics', 'Bedding', 'Beauty Products', 'Gardening Supplies', 'Stationery']
# ['Beauty Products', 'Electronics']
# ['Furniture', 'Clothes', 'Electronics']
# ['Electronics', 'Cleaning Supplies']
# ['Gardening Supplies', 'Clothes', 'Furniture', 'Bedding', 'Beauty Products']
# ['Furniture', 'Cleaning Supplies']
# ['Bedding', 'Toys', 'Cleaning Supplies', 'Gardening Supplies']
# ['Electronics', 'Stationery', 'Clothes', 'Gardening Supplies', 'Cleaning Supplies']
# ['Furniture', 'Electronics']
# ['Electronics', 'Toys', 'Gardening Supplies', 'Furniture']
# ['Electronics', 'Stationery', 'Toys']
# ['Bedding', 'Gardening Supplies']
# ['Clothes', 'Furniture']
# ['Groceries', 'Furniture', 'Beauty Products', 'Toys', 'Stationery']
# ['Gardening Supplies', 'Clothes', 'Toys', 'Furniture', 'Bedding']
# ['Furniture', 'Gardening Supplies', 'Beauty Products']
# ['Beauty Products', 'Clothes', 'Furniture']
# ['Stationery', 'Cleaning Supplies']
# ['Furniture', 'Toys']
# ['Stationery', 'Furniture', 'Gardening Supplies']
# ['Groceries', 'Stationery', 'Furniture']
# ['Groceries', 'Stationery', 'Furniture', 'Beauty Products']
# ['Gardening Supplies', 'Stationery', 'Beauty Products', 'Electronics']
# ['Gardening Supplies', 'Bedding']
# ['Cleaning Supplies', 'Clothes', 'Gardening Supplies', 'Toys', 'Electronics']
# ['Electronics', 'Beauty Products', 'Groceries', 'Furniture']
# ['Beauty Products', 'Stationery', 'Toys']
# ['Beauty Products', 'Gardening Supplies']
# ['Electronics', 'Clothes', 'Stationery']
# ['Cleaning Supplies', 'Furniture', 'Clothes']
# ['Toys', 'Furniture']
# ['Furniture', 'Toys', 'Beauty Products', 'Groceries']
# ['Toys', 'Groceries', 'Gardening Supplies', 'Bedding']
# ['Clothes', 'Bedding', 'Stationery', 'Beauty Products']
# ['Furniture', 'Electronics']
# ['Toys', 'Bedding']
# ['Groceries', 'Gardening Supplies', 'Beauty Products', 'Bedding']
# ['Clothes', 'Stationery']
# ['Bedding', 'Groceries', 'Gardening Supplies', 'Furniture', 'Stationery']
# ['Toys', 'Gardening Supplies', 'Clothes', 'Bedding', 'Furniture']
# ['Clothes', 'Toys', 'Electronics']
# ['Beauty Products', 'Bedding', 'Clothes']
# ['Stationery', 'Gardening Supplies']
# ['Groceries', 'Electronics', 'Toys']
# ['Bedding', 'Clothes', 'Beauty Products', 'Furniture']
# ['Clothes', 'Cleaning Supplies']
# ['Gardening Supplies', 'Clothes', 'Groceries']
# ['Gardening Supplies', 'Beauty Products', 'Electronics', 'Stationery', 'Clothes']
# ['Stationery', 'Bedding', 'Furniture']
# ['Cleaning Supplies', 'Stationery', 'Furniture', 'Electronics', 'Bedding']
# ['Stationery', 'Clothes']
# ['Stationery', 'Gardening Supplies', 'Groceries', 'Furniture']
# ['Furniture', 'Bedding', 'Electronics', 'Cleaning Supplies']
# ['Electronics', 'Groceries']
# ['Beauty Products', 'Toys']
# ['Beauty Products', 'Stationery', 'Furniture']
# ['Electronics', 'Groceries', 'Cleaning Supplies', 'Toys']
# ['Gardening Supplies', 'Clothes']
# ['Furniture', 'Gardening Supplies', 'Bedding']
# ['Groceries', 'Toys']
# ['Beauty Products', 'Furniture']
# ['Gardening Supplies', 'Cleaning Supplies', 'Furniture', 'Groceries', 'Toys']
# ['Toys', 'Bedding']
# ['Groceries', 'Clothes', 'Beauty Products', 'Stationery']
# ['Gardening Supplies', 'Cleaning Supplies', 'Stationery', 'Clothes']
# ['Electronics', 'Bedding', 'Furniture', 'Groceries']
# ['Electronics', 'Furniture']
# ['Toys', 'Clothes', 'Groceries', 'Electronics', 'Gardening Supplies']
# ['Furniture', 'Electronics', 'Beauty Products', 'Groceries']
# ['Cleaning Supplies', 'Groceries', 'Gardening Supplies', 'Stationery']
# ['Bedding', 'Beauty Products', 'Furniture', 'Electronics', 'Cleaning Supplies']
# ['Beauty Products', 'Cleaning Supplies', 'Groceries']
# ['Cleaning Supplies', 'Furniture', 'Toys', 'Gardening Supplies', 'Bedding']
# ['Gardening Supplies', 'Beauty Products', 'Bedding', 'Furniture', 'Stationery']
# ['Toys', 'Bedding']
# ['Furniture', 'Toys']
# ['Electronics', 'Bedding', 'Groceries', 'Gardening Supplies', 'Stationery']
# ['Toys', 'Clothes', 'Groceries']
# ['Toys', 'Electronics']
# ['Furniture', 'Gardening Supplies', 'Clothes']
# ['Clothes', 'Groceries', 'Cleaning Supplies', 'Bedding', 'Beauty Products']
#
# Generated Association Rules:
#              antecedents          consequents   support  confidence
# 0      (Beauty Products)            (Bedding)  0.112944    0.328413
# 1              (Bedding)    (Beauty Products)  0.112944    0.328413
# 2      (Beauty Products)  (Cleaning Supplies)  0.105330    0.306273
# 3    (Cleaning Supplies)    (Beauty Products)  0.105330    0.300725
# 4      (Beauty Products)        (Electronics)  0.116751    0.339483
# ..                   ...                  ...       ...         ...
# 61  (Gardening Supplies)         (Stationery)  0.120558    0.358491
# 62           (Groceries)         (Stationery)  0.110406    0.332061
# 63           (Groceries)               (Toys)  0.104061    0.312977
# 64                (Toys)          (Groceries)  0.104061    0.319066
# 65                (Toys)         (Stationery)  0.110406    0.338521
#
# [66 rows x 4 columns]
#
# Total Execution Time: 0.03 seconds
#
# Dataset Shoprite not found. Please check your input.

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import fpgrowth, association_rules
import time

# Function to load transactions from the dataset
def load_transactions(file_path):
    # Read CSV and split the transactions by commas
    df = pd.read_csv(file_path)
    transactions = df['Filtered Transaction'].str.split(', ').tolist()
    return transactions

# Function to perform frequent itemset and association rule analysis
def perform_analysis(file_path, min_support, min_confidence):
    start_time = time.time()  # Start timing the analysis for this dataset

    # Load the transaction data
    transactions = load_transactions(file_path)
    
    # Encode the transactions into a format suitable for fpgrowth
    encoder = TransactionEncoder()
    transformed_data = encoder.fit(transactions).transform(transactions)
    transactions_df = pd.DataFrame(transformed_data, columns=encoder.columns_)
    
    # Apply the fpgrowth algorithm to find frequent itemsets
    frequent_itemsets = fpgrowth(transactions_df, min_support=min_support, use_colnames=True)
    
    # Derive association rules from the frequent itemsets
    rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)
    
    # Print the results
    print(f"\nFrequent Itemsets from {file_path.split('/')[-1]}:")
    print(frequent_itemsets)
    print("\nGenerated Association Rules:")
    print(rules[['antecedents', 'consequents', 'support', 'confidence']])
    print("\n")
    
    # Print execution time for this dataset in the required format
    print(f"Total Execution Time: {time.time() - start_time:.2f} seconds\n")

# Main function to execute the analysis based on user input
def execute_analysis():
    # Dictionary mapping dataset numbers to file paths
   datasets = {
    'Target': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\target_data_new.csv',
    'Costco': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\costco_data_new.csv',
    '7-Eleven': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\seven_eleven_data.csv',
    'ShopRite': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\shoprite_data.csv',
    'K-Mart': 'C:\\Users\\anuve\\Downloads\\dataset2\\dataset2\\kmart_data.csv'
}

    
    # Display options to the user
    print("Choose dataset(s) for analysis:")
    for index, name in enumerate(['Target', 'Costco', '7-Eleven', 'ShopRite', 'K-Mart'], start=1):
        print(f"{index} - {name}")
    
    # Accept user input for datasets and parameters
    selected_datasets = input("Enter dataset numbers (space-separated, e.g., 1 3): ").split()
    min_support_value = float(input("Enter minimum support (e.g., 0.05): "))
    min_confidence_value = float(input("Enter minimum confidence (e.g., 0.5): "))
    
    # Perform analysis for each selected dataset
    for dataset_key in selected_datasets:
        if dataset_key in datasets:
            perform_analysis(datasets[dataset_key], min_support_value, min_confidence_value)
        else:
            print(f"Invalid choice: {dataset_key}")

# Run the analysis when the script is executed
if __name__ == "__main__":
    execute_analysis()
# Out:
# Choose dataset(s) for analysis:
# 1 - Target
# 2 - Costco
# 3 - 7-Eleven
# 4 - ShopRite
# 5 - K-Mart
# Enter dataset numbers (space-separated, e.g., 1 3): 1 3
# Enter minimum support (e.g., 0.05): 0.05
# Enter minimum confidence (e.g., 0.5): 0.3
#
# Frequent Itemsets from target_data_new.csv:
#     support                                 itemsets
# 0     0.309                            (Electronics)
# 1     0.292                        (Beauty Products)
# 2     0.291                                (Bedding)
# 3     0.287                     (Gardening Supplies)
# 4     0.295                      (Cleaning Supplies)
# 5     0.286                              (Groceries)
# 6     0.329                              (Furniture)
# 7     0.287                                (Clothes)
# 8     0.320                             (Stationery)
# 9     0.278                                   (Toys)
# 10    0.098                 (Furniture, Electronics)
# 11    0.099                (Stationery, Electronics)
# 12    0.092           (Beauty Products, Electronics)
# 13    0.094             (Furniture, Beauty Products)
# 14    0.097            (Stationery, Beauty Products)
# 15    0.083     (Beauty Products, Cleaning Supplies)
# 16    0.092                   (Electronics, Bedding)
# 17    0.089               (Beauty Products, Bedding)
# 18    0.081             (Cleaning Supplies, Bedding)
# 19    0.090                     (Furniture, Bedding)
# 20    0.097                    (Stationery, Bedding)
# 21    0.087        (Electronics, Gardening Supplies)
# 22    0.085            (Gardening Supplies, Bedding)
# 23    0.082    (Beauty Products, Gardening Supplies)
# 24    0.089  (Gardening Supplies, Cleaning Supplies)
# 25    0.097          (Furniture, Gardening Supplies)
# 26    0.095         (Stationery, Gardening Supplies)
# 27    0.101           (Furniture, Cleaning Supplies)
# 28    0.097         (Electronics, Cleaning Supplies)
# 29    0.097          (Stationery, Cleaning Supplies)
# 30    0.091           (Groceries, Cleaning Supplies)
# 31    0.083          (Groceries, Gardening Supplies)
# 32    0.083                     (Groceries, Bedding)
# 33    0.100                   (Furniture, Groceries)
# 34    0.097                 (Groceries, Electronics)
# 35    0.073                     (Groceries, Clothes)
# 36    0.087                  (Stationery, Groceries)
# 37    0.079             (Groceries, Beauty Products)
# 38    0.089                     (Furniture, Clothes)
# 39    0.087             (Clothes, Cleaning Supplies)
# 40    0.081                   (Clothes, Electronics)
# 41    0.080                       (Clothes, Bedding)
# 42    0.093                    (Stationery, Clothes)
# 43    0.089            (Clothes, Gardening Supplies)
# 44    0.077               (Beauty Products, Clothes)
# 45    0.101                  (Stationery, Furniture)
# 46    0.087                       (Stationery, Toys)
# 47    0.077                          (Toys, Clothes)
# 48    0.071               (Toys, Gardening Supplies)
# 49    0.074                (Toys, Cleaning Supplies)
# 50    0.091                      (Toys, Electronics)
# 51    0.073                          (Toys, Bedding)
# 52    0.077                  (Toys, Beauty Products)
# 53    0.082                        (Groceries, Toys)
# 54    0.082                        (Furniture, Toys)
#
# Generated Association Rules:
#              antecedents           consequents  support  confidence
# 0          (Electronics)           (Furniture)    0.098    0.317152
# 1           (Stationery)         (Electronics)    0.099    0.309375
# 2          (Electronics)          (Stationery)    0.099    0.320388
# 3      (Beauty Products)         (Electronics)    0.092    0.315068
# 4      (Beauty Products)           (Furniture)    0.094    0.321918
# 5           (Stationery)     (Beauty Products)    0.097    0.303125
# 6      (Beauty Products)          (Stationery)    0.097    0.332192
# 7              (Bedding)         (Electronics)    0.092    0.316151
# 8      (Beauty Products)             (Bedding)    0.089    0.304795
# 9              (Bedding)     (Beauty Products)    0.089    0.305842
# 10             (Bedding)           (Furniture)    0.090    0.309278
# 11          (Stationery)             (Bedding)    0.097    0.303125
# 12             (Bedding)          (Stationery)    0.097    0.333333
# 13  (Gardening Supplies)         (Electronics)    0.087    0.303136
# 14  (Gardening Supplies)   (Cleaning Supplies)    0.089    0.310105
# 15   (Cleaning Supplies)  (Gardening Supplies)    0.089    0.301695
# 16  (Gardening Supplies)           (Furniture)    0.097    0.337979
# 17  (Gardening Supplies)          (Stationery)    0.095    0.331010
# 18           (Furniture)   (Cleaning Supplies)    0.101    0.306991
# 19   (Cleaning Supplies)           (Furniture)    0.101    0.342373
# 20         (Electronics)   (Cleaning Supplies)    0.097    0.313916
# 21   (Cleaning Supplies)         (Electronics)    0.097    0.328814
# 22          (Stationery)   (Cleaning Supplies)    0.097    0.303125
# 23   (Cleaning Supplies)          (Stationery)    0.097    0.328814
# 24           (Groceries)   (Cleaning Supplies)    0.091    0.318182
# 25   (Cleaning Supplies)           (Groceries)    0.091    0.308475
# 26           (Furniture)           (Groceries)    0.100    0.303951
# 27           (Groceries)           (Furniture)    0.100    0.349650
# 28           (Groceries)         (Electronics)    0.097    0.339161
# 29         (Electronics)           (Groceries)    0.097    0.313916
# 30           (Groceries)          (Stationery)    0.087    0.304196
# 31             (Clothes)           (Furniture)    0.089    0.310105
# 32             (Clothes)   (Cleaning Supplies)    0.087    0.303136
# 33             (Clothes)          (Stationery)    0.093    0.324042
# 34             (Clothes)  (Gardening Supplies)    0.089    0.310105
# 35  (Gardening Supplies)             (Clothes)    0.089    0.310105
# 36          (Stationery)           (Furniture)    0.101    0.315625
# 37           (Furniture)          (Stationery)    0.101    0.306991
# 38                (Toys)          (Stationery)    0.087    0.312950
# 39                (Toys)         (Electronics)    0.091    0.327338
#
#
# Total Execution Time: 0.05 seconds
#
#
# Frequent Itemsets from seven_eleven_data.csv:
#     support                      itemsets
# 0     0.303                         (Gum)
# 1     0.297                   (Batteries)
# 2     0.286                  (Cigarettes)
# 3     0.284               (Energy Drinks)
# 4     0.271                      (Snacks)
# 5     0.318                    (Magazine)
# 6     0.321                       (Candy)
# 7     0.314                        (Milk)
# 8     0.280                  (Toiletries)
# 9     0.274                 (Soft Drinks)
# 10    0.095                  (Gum, Candy)
# 11    0.093                   (Gum, Milk)
# 12    0.109               (Magazine, Gum)
# 13    0.093              (Gum, Batteries)
# 14    0.108            (Candy, Batteries)
# 15    0.100             (Batteries, Milk)
# 16    0.091         (Magazine, Batteries)
# 17    0.093       (Cigarettes, Batteries)
# 18    0.088             (Gum, Cigarettes)
# 19    0.085           (Cigarettes, Candy)
# 20    0.092            (Cigarettes, Milk)
# 21    0.088        (Magazine, Cigarettes)
# 22    0.099          (Energy Drinks, Gum)
# 23    0.095   (Energy Drinks, Cigarettes)
# 24    0.064    (Energy Drinks, Batteries)
# 25    0.089        (Energy Drinks, Candy)
# 26    0.077     (Magazine, Energy Drinks)
# 27    0.082         (Energy Drinks, Milk)
# 28    0.082                 (Gum, Snacks)
# 29    0.075       (Energy Drinks, Snacks)
# 30    0.071          (Cigarettes, Snacks)
# 31    0.070           (Batteries, Snacks)
# 32    0.075            (Magazine, Snacks)
# 33    0.084               (Candy, Snacks)
# 34    0.068          (Toiletries, Snacks)
# 35    0.081                (Milk, Snacks)
# 36    0.078         (Snacks, Soft Drinks)
# 37    0.099             (Magazine, Candy)
# 38    0.101                 (Candy, Milk)
# 39    0.098              (Magazine, Milk)
# 40    0.101            (Toiletries, Milk)
# 41    0.085             (Gum, Toiletries)
# 42    0.079       (Toiletries, Batteries)
# 43    0.099           (Toiletries, Candy)
# 44    0.086   (Energy Drinks, Toiletries)
# 45    0.085        (Magazine, Toiletries)
# 46    0.069      (Toiletries, Cigarettes)
# 47    0.090          (Candy, Soft Drinks)
# 48    0.084           (Milk, Soft Drinks)
# 49    0.076      (Batteries, Soft Drinks)
# 50    0.077            (Gum, Soft Drinks)
# 51    0.070     (Toiletries, Soft Drinks)
# 52    0.072  (Energy Drinks, Soft Drinks)
# 53    0.086       (Magazine, Soft Drinks)
# 54    0.078     (Cigarettes, Soft Drinks)
#
# Generated Association Rules:
#         antecedents      consequents  support  confidence
# 0             (Gum)          (Candy)    0.095    0.313531
# 1             (Gum)           (Milk)    0.093    0.306931
# 2        (Magazine)            (Gum)    0.109    0.342767
# 3             (Gum)       (Magazine)    0.109    0.359736
# 4             (Gum)      (Batteries)    0.093    0.306931
# 5       (Batteries)            (Gum)    0.093    0.313131
# 6           (Candy)      (Batteries)    0.108    0.336449
# 7       (Batteries)          (Candy)    0.108    0.363636
# 8       (Batteries)           (Milk)    0.100    0.336700
# 9            (Milk)      (Batteries)    0.100    0.318471
# 10      (Batteries)       (Magazine)    0.091    0.306397
# 11     (Cigarettes)      (Batteries)    0.093    0.325175
# 12      (Batteries)     (Cigarettes)    0.093    0.313131
# 13     (Cigarettes)            (Gum)    0.088    0.307692
# 14     (Cigarettes)           (Milk)    0.092    0.321678
# 15     (Cigarettes)       (Magazine)    0.088    0.307692
# 16  (Energy Drinks)            (Gum)    0.099    0.348592
# 17            (Gum)  (Energy Drinks)    0.099    0.326733
# 18  (Energy Drinks)     (Cigarettes)    0.095    0.334507
# 19     (Cigarettes)  (Energy Drinks)    0.095    0.332168
# 20  (Energy Drinks)          (Candy)    0.089    0.313380
# 21         (Snacks)            (Gum)    0.082    0.302583
# 22         (Snacks)          (Candy)    0.084    0.309963
# 23       (Magazine)          (Candy)    0.099    0.311321
# 24          (Candy)       (Magazine)    0.099    0.308411
# 25          (Candy)           (Milk)    0.101    0.314642
# 26           (Milk)          (Candy)    0.101    0.321656
# 27       (Magazine)           (Milk)    0.098    0.308176
# 28           (Milk)       (Magazine)    0.098    0.312102
# 29     (Toiletries)           (Milk)    0.101    0.360714
# 30           (Milk)     (Toiletries)    0.101    0.321656
# 31     (Toiletries)            (Gum)    0.085    0.303571
# 32     (Toiletries)          (Candy)    0.099    0.353571
# 33          (Candy)     (Toiletries)    0.099    0.308411
# 34  (Energy Drinks)     (Toiletries)    0.086    0.302817
# 35     (Toiletries)  (Energy Drinks)    0.086    0.307143
# 36     (Toiletries)       (Magazine)    0.085    0.303571
# 37    (Soft Drinks)          (Candy)    0.090    0.328467
# 38    (Soft Drinks)           (Milk)    0.084    0.306569
# 39    (Soft Drinks)       (Magazine)    0.086    0.313869
#
#
# Total Execution Time: 0.02 seconds
